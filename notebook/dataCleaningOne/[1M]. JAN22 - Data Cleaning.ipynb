# %% [markdown]
# # JAN22 - Data Cleaning

# %% [markdown]
# ## Data Gather

# %% [markdown]
# ### Importing libraries and load the datasets

# %%
from datetime import datetime
import pandas as pd
from openpyxl import Workbook
import numpy as np

# %%
#  Load the datasets
df = pd.read_excel(r"..\..\data\gatherData\JAN22_DimsumTJOEAN.xlsx")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   DATE         16 non-null     datetime64[ns]
#  1   DEBIT        7 non-null      object
#  2   CREDIT       23 non-null     object
#  3   RECIPIENT    19 non-null     object
#  4   30           16 non-null     float64
#  5   20           8 non-null      float64
#  6   10           6 non-null      float64
#  7   L            10 non-null     float64
#  8   R            6 non-null      float64
#  9   PIC          16 non-null     object
#  10  Unnamed: 10  2 non-null      object
# dtypes: datetime64[ns](1), float64(5), object(5)
# memory usage: 3.1+ KB

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Inconsistent Data **#1**

# %% [markdown]
# #### Delete `NaN` rows and the inconsistent rows that we don't use

# %% [markdown]
# ##### Delete `NaN` rows

# %%
df.tail()
# Out:
#    DATE    DEBIT     CREDIT RECIPIENT     30    20    10   L   R  PIC  \
# 29  NaT    ambun  10 shumai       NaN    NaN   NaN   NaN NaN NaN  NaN
# 30  NaT      NaN  20 lumpia       NaN    NaN   NaN   NaN NaN NaN  NaN
# 31  NaT      NaN  2 rendang       NaN    NaN   NaN   NaN NaN NaN  NaN
# 32  NaT      NaN        NaN       NaN    NaN   NaN   NaN NaN NaN  NaN
# 33  NaT  PIUTANG        NaN       600  450.0  80.0  70.0 NaN NaN  NaN
#
#    Unnamed: 10
# 29         NaN
# 30         NaN
# 31         NaN
# 32         NaN
# 33         NaN

# %%
# Rows to drop
rowsToDrop = df[df.isnull().all(axis=1)].index
rowsToDrop
# In a beginning of rows, there are also a 'NaN' values
# Out:
# Index([16, 19, 20, 23, 28, 32], dtype='int64')

# %%
# Delete based on the condition
df = df.drop(index=rowsToDrop)

# %%
df.tail()
# There isn't the all columns have 'NaN' values
# Out:
#    DATE    DEBIT     CREDIT RECIPIENT     30    20    10   L   R  PIC  \
# 27  NaT      NaN  2 rendang       NaN    NaN   NaN   NaN NaN NaN  NaN
# 29  NaT    ambun  10 shumai       NaN    NaN   NaN   NaN NaN NaN  NaN
# 30  NaT      NaN  20 lumpia       NaN    NaN   NaN   NaN NaN NaN  NaN
# 31  NaT      NaN  2 rendang       NaN    NaN   NaN   NaN NaN NaN  NaN
# 33  NaT  PIUTANG        NaN       600  450.0  80.0  70.0 NaN NaN  NaN
#
#    Unnamed: 10
# 27         NaN
# 29         NaN
# 30         NaN
# 31         NaN
# 33         NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 28 entries, 0 to 33
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   DATE         16 non-null     datetime64[ns]
#  1   DEBIT        7 non-null      object
#  2   CREDIT       23 non-null     object
#  3   RECIPIENT    19 non-null     object
#  4   30           16 non-null     float64
#  5   20           8 non-null      float64
#  6   10           6 non-null      float64
#  7   L            10 non-null     float64
#  8   R            6 non-null      float64
#  9   PIC          16 non-null     object
#  10  Unnamed: 10  2 non-null      object
# dtypes: datetime64[ns](1), float64(5), object(5)
# memory usage: 2.6+ KB

# %% [markdown]
# ##### Delete the inconsistent rows that we don't use

# %%
df.head()
# Out:
#         DATE DEBIT     CREDIT   RECIPIENT    30    20    10     L     R  \
# 0 2022-01-01   NaN  165107025      2021's  32.0  13.0  17.0  23.0  11.0
# 1 2022-01-04   NaN     200000        inge   2.0   NaN   NaN   NaN   NaN
# 2 2022-01-05   NaN     145000     kak ega   1.0   NaN   NaN   1.0   NaN
# 3 2022-01-04   NaN     200000       clara   2.0   NaN   NaN   NaN   NaN
# 4 2022-01-07   NaN     250000  Tante Maya   NaN   NaN   NaN   NaN   2.0
#
#      PIC      Unnamed: 10
# 0    NaN              NaN
# 1  Manda              NaN
# 2  Manda  bonus 10 lumpia
# 3  Manda              NaN
# 4  Ambun              NaN

# %%
df.tail(6)
# Out:
#    DATE    DEBIT     CREDIT RECIPIENT       30      20      10       L   R  \
# 26  NaT      NaN  20 lumpia     37940  20640.0  5840.0  3450.0  8010.0 NaN
# 27  NaT      NaN  2 rendang       NaN      NaN     NaN     NaN     NaN NaN
# 29  NaT    ambun  10 shumai       NaN      NaN     NaN     NaN     NaN NaN
# 30  NaT      NaN  20 lumpia       NaN      NaN     NaN     NaN     NaN NaN
# 31  NaT      NaN  2 rendang       NaN      NaN     NaN     NaN     NaN NaN
# 33  NaT  PIUTANG        NaN       600    450.0    80.0    70.0     NaN NaN
#
#     PIC Unnamed: 10
# 26  NaN         NaN
# 27  NaN         NaN
# 29  NaN         NaN
# 30  NaN         NaN
# 31  NaN         NaN
# 33  NaN         NaN

# %%
# Condition where 'PIC' column values is not Manda and Ambun
rowsToDropIsNotPIC = df[~(df['PIC'].isin(['Manda', 'Ambun']))].index
rowsToDropIsNotPIC
# Out:
# Index([0, 14, 15, 17, 18, 21, 22, 24, 25, 26, 27, 29, 30, 31, 33], dtype='int64')

# %%
# Delete based on the condition
df = df.drop(index=rowsToDropIsNotPIC)

# Adjust the index in ascending from start until finish
df = df.reset_index(drop=True)

# %%
df.info()
# Successfully adjust
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   DATE         13 non-null     datetime64[ns]
#  1   DEBIT        0 non-null      object
#  2   CREDIT       13 non-null     object
#  3   RECIPIENT    13 non-null     object
#  4   30           9 non-null      float64
#  5   20           3 non-null      float64
#  6   10           1 non-null      float64
#  7   L            6 non-null      float64
#  8   R            3 non-null      float64
#  9   PIC          13 non-null     object
#  10  Unnamed: 10  2 non-null      object
# dtypes: datetime64[ns](1), float64(5), object(5)
# memory usage: 1.2+ KB

# %%
df.head()
# The first rows that we don't use is successfully deleted
# Out:
#         DATE DEBIT   CREDIT          RECIPIENT   30    20    10     L    R  \
# 0 2022-01-04   NaN   200000               inge  2.0   NaN   NaN   NaN  NaN
# 1 2022-01-05   NaN   145000            kak ega  1.0   NaN   NaN   1.0  NaN
# 2 2022-01-04   NaN   200000              clara  2.0   NaN   NaN   NaN  NaN
# 3 2022-01-07   NaN   250000         Tante Maya  NaN   NaN   NaN   NaN  2.0
# 4 2022-01-12   NaN  4154000  ALDHIRA's WEDDING  NaN  19.0  19.0  19.0  2.0
#
#      PIC      Unnamed: 10
# 0  Manda              NaN
# 1  Manda  bonus 10 lumpia
# 2  Manda              NaN
# 3  Ambun              NaN
# 4  Manda              NaN

# %%
df.tail()
# The last rows that we don't use is successfully deleted
# Out:
#          DATE DEBIT  CREDIT           RECIPIENT   30   20  10    L   R    PIC  \
# 8  2022-01-17   NaN  215000                ravi  NaN  1.0 NaN  3.0 NaN  Manda
# 9  2022-01-17   NaN  225000              nabila  NaN  NaN NaN  5.0 NaN  Manda
# 10 2022-01-25   NaN  190000  Uti for Tante Susi  1.0  NaN NaN  2.0 NaN  Ambun
# 11 2022-01-29   NaN  245000                Aria  2.0  NaN NaN  1.0 NaN  Ambun
# 12 2022-01-23   NaN  300000                aziz  3.0  NaN NaN  NaN NaN  Manda
#
#         Unnamed: 10
# 8               NaN
# 9               NaN
# 10              NaN
# 11  bonus chili oil
# 12              NaN

# %% [markdown]
# #### Rename `30`, `20`, `10`, `L` columns to make it easier to understand

# %%
df[[30, 20, 10, 'L']].head()
# Out:
#     30    20    10     L
# 0  2.0   NaN   NaN   NaN
# 1  1.0   NaN   NaN   1.0
# 2  2.0   NaN   NaN   NaN
# 3  NaN   NaN   NaN   NaN
# 4  NaN  19.0  19.0  19.0

# %%
# Rename the columns to improve readability
df = df.rename(columns={30:'Shumai 30 Pcs', 20:'Shumai 20 Pcs', 10:'Shumai 10 Pcs', 'L':'Chicken Lumpia 10 Pcs'})

# %%
df[['Shumai 30 Pcs', 'Shumai 20 Pcs', 'Shumai 10 Pcs', 'Chicken Lumpia 10 Pcs']]
# Now, it's getting better
# Out:
#     Shumai 30 Pcs  Shumai 20 Pcs  Shumai 10 Pcs  Chicken Lumpia 10 Pcs
# 0             2.0            NaN            NaN                    NaN
# 1             1.0            NaN            NaN                    1.0
# 2             2.0            NaN            NaN                    NaN
# 3             NaN            NaN            NaN                    NaN
# 4             NaN           19.0           19.0                   19.0
# 5             1.0            2.0            NaN                    NaN
# 6             1.0            NaN            NaN                    NaN
# 7             1.0            NaN            NaN                    NaN
# 8             NaN            1.0            NaN                    3.0
# 9             NaN            NaN            NaN                    5.0
# 10            1.0            NaN            NaN                    2.0
# 11            2.0            NaN            NaN                    1.0
# 12            3.0            NaN            NaN                    NaN

# %%
df.head()
# Out:
#         DATE DEBIT   CREDIT          RECIPIENT  Shumai 30 Pcs  Shumai 20 Pcs  \
# 0 2022-01-04   NaN   200000               inge            2.0            NaN
# 1 2022-01-05   NaN   145000            kak ega            1.0            NaN
# 2 2022-01-04   NaN   200000              clara            2.0            NaN
# 3 2022-01-07   NaN   250000         Tante Maya            NaN            NaN
# 4 2022-01-12   NaN  4154000  ALDHIRA's WEDDING            NaN           19.0
#
#    Shumai 10 Pcs  Chicken Lumpia 10 Pcs    R    PIC      Unnamed: 10
# 0            NaN                    NaN  NaN  Manda              NaN
# 1            NaN                    1.0  NaN  Manda  bonus 10 lumpia
# 2            NaN                    NaN  NaN  Manda              NaN
# 3            NaN                    NaN  2.0  Ambun              NaN
# 4           19.0                   19.0  2.0  Manda              NaN

# %% [markdown]
# ### Missing Value

# %% [markdown]
# #### Impute missing values of `DATE` column with mode

# %%
df.info();
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   DATE                   13 non-null     datetime64[ns]
#  1   DEBIT                  0 non-null      object
#  2   CREDIT                 13 non-null     object
#  3   RECIPIENT              13 non-null     object
#  4   Shumai 30 Pcs          9 non-null      float64
#  5   Shumai 20 Pcs          3 non-null      float64
#  6   Shumai 10 Pcs          1 non-null      float64
#  7   Chicken Lumpia 10 Pcs  6 non-null      float64
#  8   R                      3 non-null      float64
#  9   PIC                    13 non-null     object
#  10  Unnamed: 10            2 non-null      object
# dtypes: datetime64[ns](1), float64(5), object(5)
# memory usage: 1.2+ KB
#         DATE DEBIT   CREDIT          RECIPIENT  Shumai 30 Pcs  Shumai 20 Pcs  \
# 0 2022-01-04   NaN   200000               inge            2.0            NaN
# 1 2022-01-05   NaN   145000            kak ega            1.0            NaN
# 2 2022-01-04   NaN   200000              clara            2.0            NaN
# 3 2022-01-07   NaN   250000         Tante Maya            NaN            NaN
# 4 2022-01-12   NaN  4154000  ALDHIRA's WEDDING            NaN           19.0
#
#    Shumai 10 Pcs  Chicken Lumpia 10 Pcs    R    PIC      Unnamed: 10
# 0            NaN                    NaN  NaN  Manda              NaN
# 1            NaN                    1.0  NaN  Manda  bonus 10 lumpia
# 2            NaN                    NaN  NaN  Manda              NaN
# 3            NaN                    NaN  2.0  Ambun              NaN
# 4           19.0                   19.0  2.0  Manda              NaN

# %%
df['DATE'].mode()
# Out:
# 0   2022-01-04
# 1   2022-01-17
# 2   2022-01-18
# Name: DATE, dtype: datetime64[ns]

# %%
# Impute missing values of `DATE` column with mode
df['DATE'] = df['DATE'].fillna(df['DATE'].mode()[0])

# %%
df.info();
df.head()
# Successfully fill with mode
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   DATE                   13 non-null     datetime64[ns]
#  1   DEBIT                  0 non-null      object
#  2   CREDIT                 13 non-null     object
#  3   RECIPIENT              13 non-null     object
#  4   Shumai 30 Pcs          9 non-null      float64
#  5   Shumai 20 Pcs          3 non-null      float64
#  6   Shumai 10 Pcs          1 non-null      float64
#  7   Chicken Lumpia 10 Pcs  6 non-null      float64
#  8   R                      3 non-null      float64
#  9   PIC                    13 non-null     object
#  10  Unnamed: 10            2 non-null      object
# dtypes: datetime64[ns](1), float64(5), object(5)
# memory usage: 1.2+ KB
#         DATE DEBIT   CREDIT          RECIPIENT  Shumai 30 Pcs  Shumai 20 Pcs  \
# 0 2022-01-04   NaN   200000               inge            2.0            NaN
# 1 2022-01-05   NaN   145000            kak ega            1.0            NaN
# 2 2022-01-04   NaN   200000              clara            2.0            NaN
# 3 2022-01-07   NaN   250000         Tante Maya            NaN            NaN
# 4 2022-01-12   NaN  4154000  ALDHIRA's WEDDING            NaN           19.0
#
#    Shumai 10 Pcs  Chicken Lumpia 10 Pcs    R    PIC      Unnamed: 10
# 0            NaN                    NaN  NaN  Manda              NaN
# 1            NaN                    1.0  NaN  Manda  bonus 10 lumpia
# 2            NaN                    NaN  NaN  Manda              NaN
# 3            NaN                    NaN  2.0  Ambun              NaN
# 4           19.0                   19.0  2.0  Manda              NaN

# %% [markdown]
# #### Impute missing values of `Shumai 10 Pcs`, `Shumai 20 Pcs`, `Shumai 30 Pcs`, `Chicken Lumpia 10 Pcs` column with 0

# %%
df.info();
df.head()
# As you can see, there's null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   DATE                   13 non-null     datetime64[ns]
#  1   DEBIT                  0 non-null      object
#  2   CREDIT                 13 non-null     object
#  3   RECIPIENT              13 non-null     object
#  4   Shumai 30 Pcs          9 non-null      float64
#  5   Shumai 20 Pcs          3 non-null      float64
#  6   Shumai 10 Pcs          1 non-null      float64
#  7   Chicken Lumpia 10 Pcs  6 non-null      float64
#  8   R                      3 non-null      float64
#  9   PIC                    13 non-null     object
#  10  Unnamed: 10            2 non-null      object
# dtypes: datetime64[ns](1), float64(5), object(5)
# memory usage: 1.2+ KB
#         DATE DEBIT   CREDIT          RECIPIENT  Shumai 30 Pcs  Shumai 20 Pcs  \
# 0 2022-01-04   NaN   200000               inge            2.0            NaN
# 1 2022-01-05   NaN   145000            kak ega            1.0            NaN
# 2 2022-01-04   NaN   200000              clara            2.0            NaN
# 3 2022-01-07   NaN   250000         Tante Maya            NaN            NaN
# 4 2022-01-12   NaN  4154000  ALDHIRA's WEDDING            NaN           19.0
#
#    Shumai 10 Pcs  Chicken Lumpia 10 Pcs    R    PIC      Unnamed: 10
# 0            NaN                    NaN  NaN  Manda              NaN
# 1            NaN                    1.0  NaN  Manda  bonus 10 lumpia
# 2            NaN                    NaN  NaN  Manda              NaN
# 3            NaN                    NaN  2.0  Ambun              NaN
# 4           19.0                   19.0  2.0  Manda              NaN

# %%
# List of columns
listOfProducts = ['Shumai 10 Pcs', 'Shumai 20 Pcs', 'Shumai 30 Pcs', 'Chicken Lumpia 10 Pcs']

# Impute missing values of products column with 0 
for cols in listOfProducts:
    for i in range(1, len(df)+1):
        df[cols] = df[cols].fillna(0)

df.info();
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   DATE                   13 non-null     datetime64[ns]
#  1   DEBIT                  0 non-null      object
#  2   CREDIT                 13 non-null     object
#  3   RECIPIENT              13 non-null     object
#  4   Shumai 30 Pcs          13 non-null     float64
#  5   Shumai 20 Pcs          13 non-null     float64
#  6   Shumai 10 Pcs          13 non-null     float64
#  7   Chicken Lumpia 10 Pcs  13 non-null     float64
#  8   R                      3 non-null      float64
#  9   PIC                    13 non-null     object
#  10  Unnamed: 10            2 non-null      object
# dtypes: datetime64[ns](1), float64(5), object(5)
# memory usage: 1.2+ KB
#         DATE DEBIT   CREDIT          RECIPIENT  Shumai 30 Pcs  Shumai 20 Pcs  \
# 0 2022-01-04   NaN   200000               inge            2.0            0.0
# 1 2022-01-05   NaN   145000            kak ega            1.0            0.0
# 2 2022-01-04   NaN   200000              clara            2.0            0.0
# 3 2022-01-07   NaN   250000         Tante Maya            0.0            0.0
# 4 2022-01-12   NaN  4154000  ALDHIRA's WEDDING            0.0           19.0
#
#    Shumai 10 Pcs  Chicken Lumpia 10 Pcs    R    PIC      Unnamed: 10
# 0            0.0                    0.0  NaN  Manda              NaN
# 1            0.0                    1.0  NaN  Manda  bonus 10 lumpia
# 2            0.0                    0.0  NaN  Manda              NaN
# 3            0.0                    0.0  2.0  Ambun              NaN
# 4           19.0                   19.0  2.0  Manda              NaN

# %% [markdown]
# ### Inconsistent Data **#2**

# %% [markdown]
# #### Convert the products category sales columns into integer

# %%
# Before convert the datatypes, we must ensure that the columns are not int
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   DATE                   13 non-null     datetime64[ns]
#  1   DEBIT                  0 non-null      object
#  2   CREDIT                 13 non-null     object
#  3   RECIPIENT              13 non-null     object
#  4   Shumai 30 Pcs          13 non-null     float64
#  5   Shumai 20 Pcs          13 non-null     float64
#  6   Shumai 10 Pcs          13 non-null     float64
#  7   Chicken Lumpia 10 Pcs  13 non-null     float64
#  8   R                      3 non-null      float64
#  9   PIC                    13 non-null     object
#  10  Unnamed: 10            2 non-null      object
# dtypes: datetime64[ns](1), float64(5), object(5)
# memory usage: 1.2+ KB

# %%
# List of columns
listOfProducts = ['Shumai 10 Pcs', 'Shumai 20 Pcs', 'Shumai 30 Pcs', 'Chicken Lumpia 10 Pcs']

# Convert into int64
for cols in listOfProducts:
    for i in range(1, len(df)+1):
        df[cols] = df[cols].astype('int64')

df.info();
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   DATE                   13 non-null     datetime64[ns]
#  1   DEBIT                  0 non-null      object
#  2   CREDIT                 13 non-null     object
#  3   RECIPIENT              13 non-null     object
#  4   Shumai 30 Pcs          13 non-null     int64
#  5   Shumai 20 Pcs          13 non-null     int64
#  6   Shumai 10 Pcs          13 non-null     int64
#  7   Chicken Lumpia 10 Pcs  13 non-null     int64
#  8   R                      3 non-null      float64
#  9   PIC                    13 non-null     object
#  10  Unnamed: 10            2 non-null      object
# dtypes: datetime64[ns](1), float64(1), int64(4), object(5)
# memory usage: 1.2+ KB
#         DATE DEBIT   CREDIT          RECIPIENT  Shumai 30 Pcs  Shumai 20 Pcs  \
# 0 2022-01-04   NaN   200000               inge              2              0
# 1 2022-01-05   NaN   145000            kak ega              1              0
# 2 2022-01-04   NaN   200000              clara              2              0
# 3 2022-01-07   NaN   250000         Tante Maya              0              0
# 4 2022-01-12   NaN  4154000  ALDHIRA's WEDDING              0             19
#
#    Shumai 10 Pcs  Chicken Lumpia 10 Pcs    R    PIC      Unnamed: 10
# 0              0                      0  NaN  Manda              NaN
# 1              0                      1  NaN  Manda  bonus 10 lumpia
# 2              0                      0  NaN  Manda              NaN
# 3              0                      0  2.0  Ambun              NaN
# 4             19                     19  2.0  Manda              NaN

# %% [markdown]
# ## Data Selection

# %% [markdown]
# ### Select certain data

# %%
df.info();
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   DATE                   13 non-null     datetime64[ns]
#  1   DEBIT                  0 non-null      object
#  2   CREDIT                 13 non-null     object
#  3   RECIPIENT              13 non-null     object
#  4   Shumai 30 Pcs          13 non-null     int64
#  5   Shumai 20 Pcs          13 non-null     int64
#  6   Shumai 10 Pcs          13 non-null     int64
#  7   Chicken Lumpia 10 Pcs  13 non-null     int64
#  8   R                      3 non-null      float64
#  9   PIC                    13 non-null     object
#  10  Unnamed: 10            2 non-null      object
# dtypes: datetime64[ns](1), float64(1), int64(4), object(5)
# memory usage: 1.2+ KB
#         DATE DEBIT   CREDIT          RECIPIENT  Shumai 30 Pcs  Shumai 20 Pcs  \
# 0 2022-01-04   NaN   200000               inge              2              0
# 1 2022-01-05   NaN   145000            kak ega              1              0
# 2 2022-01-04   NaN   200000              clara              2              0
# 3 2022-01-07   NaN   250000         Tante Maya              0              0
# 4 2022-01-12   NaN  4154000  ALDHIRA's WEDDING              0             19
#
#    Shumai 10 Pcs  Chicken Lumpia 10 Pcs    R    PIC      Unnamed: 10
# 0              0                      0  NaN  Manda              NaN
# 1              0                      1  NaN  Manda  bonus 10 lumpia
# 2              0                      0  NaN  Manda              NaN
# 3              0                      0  2.0  Ambun              NaN
# 4             19                     19  2.0  Manda              NaN

# %%
# Delete `DEBIT`, `CREDIT`, `RECIPIENT`, `PIC`, `R` since we don't use it
df = df.drop(columns=['DEBIT', 'CREDIT', 'RECIPIENT', 'PIC', 'R'])

# Index of 'Chicken Lumpia 10 Pcs'
chickenLumpiaIndex = df.columns.get_loc('Chicken Lumpia 10 Pcs')

# Take all columns before chickenLumpiaIndex position
df = df.iloc[:, :chickenLumpiaIndex + 1]

df.info();
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   DATE                   13 non-null     datetime64[ns]
#  1   Shumai 30 Pcs          13 non-null     int64
#  2   Shumai 20 Pcs          13 non-null     int64
#  3   Shumai 10 Pcs          13 non-null     int64
#  4   Chicken Lumpia 10 Pcs  13 non-null     int64
# dtypes: datetime64[ns](1), int64(4)
# memory usage: 652.0 bytes
#         DATE  Shumai 30 Pcs  Shumai 20 Pcs  Shumai 10 Pcs  \
# 0 2022-01-04              2              0              0
# 1 2022-01-05              1              0              0
# 2 2022-01-04              2              0              0
# 3 2022-01-07              0              0              0
# 4 2022-01-12              0             19             19
#
#    Chicken Lumpia 10 Pcs
# 0                      0
# 1                      1
# 2                      0
# 3                      0
# 4                     19

# %% [markdown]
# ## Export the dataframe into excel files

# %%
# Load datasets and convert it into excel based on month of sales's sheets
df = df.to_excel(r"..\..\data\dataCleaningOne\JAN22_dataCleaning.xlsx", index=False)

# %%
# selecting columns where column name contains 'Average' string
# df.filter(like='Average')
