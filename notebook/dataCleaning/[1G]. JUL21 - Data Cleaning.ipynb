# %% [markdown]
# # JUL21 - Data Cleaning

# %% [markdown]
# ## Data Gather

# %% [markdown]
# ### Importing libraries and load the datasets

# %%
from datetime import datetime
import pandas as pd
from openpyxl import Workbook
import numpy as np

# %%
#  Load the datasets
df = pd.read_excel(r"..\..\data\gatherData\JUL21_DimsumTJOEAN.xlsx")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   DATE         68 non-null     datetime64[ns]
#  1   DEBIT        9 non-null      object
#  2   CREDIT       72 non-null     object
#  3   RECIPIENT    71 non-null     object
#  4   30           42 non-null     float64
#  5   20           21 non-null     float64
#  6   10           11 non-null     float64
#  7   L            35 non-null     float64
#  8   R            28 non-null     float64
#  9   PIC          68 non-null     object
#  10  Unnamed: 10  6 non-null      object
# dtypes: datetime64[ns](1), float64(5), object(5)
# memory usage: 8.0+ KB

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Inconsistent Data **#1**

# %% [markdown]
# #### Delete `NaN` rows and the inconsistent rows that we don't use

# %% [markdown]
# ##### Delete `NaN` rows

# %%
df.tail()
# Out:
#    DATE                  DEBIT CREDIT RECIPIENT  30  20  10   L   R  PIC  \
# 87  NaT                    NaN    NaN       NaN NaN NaN NaN NaN NaN  NaN
# 88  NaT  utang rendang bunda 2    NaN       NaN NaN NaN NaN NaN NaN  NaN
# 89  NaT                    NaN    NaN       NaN NaN NaN NaN NaN NaN  NaN
# 90  NaT                    NaN    NaN       NaN NaN NaN NaN NaN NaN  NaN
# 91  NaT  manda utang rendang 1    NaN       NaN NaN NaN NaN NaN NaN  NaN
#
#    Unnamed: 10
# 87         NaN
# 88         NaN
# 89         NaN
# 90         NaN
# 91         NaN

# %%
# Rows to drop
rowsToDrop = df[df.isnull().all(axis=1)].index
rowsToDrop
# In a beginning of rows, there are also a 'NaN' values
# Out:
# Index([68, 71, 72, 75, 80, 82, 83, 84, 86, 87, 89, 90], dtype='int64')

# %%
# Delete based on the condition
df = df.drop(index=rowsToDrop)

# %%
df.tail()
# There isn't the all columns have 'NaN' values
# Out:
#    DATE                  DEBIT     CREDIT RECIPIENT     30    20    10   L  \
# 79  NaT                    NaN  1 rendang       NaN    NaN   NaN   NaN NaN
# 81  NaT                  ambun  40 shumai       NaN    NaN   NaN   NaN NaN
# 85  NaT                PIUTANG        NaN       600  450.0  80.0  70.0 NaN
# 88  NaT  utang rendang bunda 2        NaN       NaN    NaN   NaN   NaN NaN
# 91  NaT  manda utang rendang 1        NaN       NaN    NaN   NaN   NaN NaN
#
#      R  PIC Unnamed: 10
# 79 NaN  NaN         NaN
# 81 NaN  NaN         NaN
# 85 NaN  NaN         NaN
# 88 NaN  NaN         NaN
# 91 NaN  NaN         NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 80 entries, 0 to 91
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   DATE         68 non-null     datetime64[ns]
#  1   DEBIT        9 non-null      object
#  2   CREDIT       72 non-null     object
#  3   RECIPIENT    71 non-null     object
#  4   30           42 non-null     float64
#  5   20           21 non-null     float64
#  6   10           11 non-null     float64
#  7   L            35 non-null     float64
#  8   R            28 non-null     float64
#  9   PIC          68 non-null     object
#  10  Unnamed: 10  6 non-null      object
# dtypes: datetime64[ns](1), float64(5), object(5)
# memory usage: 7.5+ KB

# %% [markdown]
# ##### Delete the inconsistent rows that we don't use

# %%
df.head()
# Out:
#         DATE DEBIT    CREDIT    RECIPIENT    30   20    10     L     R    PIC  \
# 0 2021-07-01   NaN  94759000       June's  30.0  8.0  11.0  40.0  20.0    NaN
# 1 2021-07-02   NaN    575000        Saras   2.0  NaN   NaN   NaN   3.0  Manda
# 2 2021-07-02   NaN    125000       athina   NaN  1.0   NaN   1.0   NaN  Manda
# 3 2021-07-03   NaN    360000  Mas dhaniar   1.0  NaN   NaN   3.0   1.0  Manda
# 4 2021-07-03   NaN     80000       Dimjie   NaN  1.0   NaN   NaN   NaN  Manda
#
#   Unnamed: 10
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
df.tail(6)
# Out:
#    DATE                  DEBIT     CREDIT RECIPIENT       30      20      10  \
# 78  NaT                    NaN        NaN     23390  14220.0  3060.0  1520.0
# 79  NaT                    NaN  1 rendang       NaN      NaN     NaN     NaN
# 81  NaT                  ambun  40 shumai       NaN      NaN     NaN     NaN
# 85  NaT                PIUTANG        NaN       600    450.0    80.0    70.0
# 88  NaT  utang rendang bunda 2        NaN       NaN      NaN     NaN     NaN
# 91  NaT  manda utang rendang 1        NaN       NaN      NaN     NaN     NaN
#
#          L   R  PIC Unnamed: 10
# 78  4590.0 NaN  NaN         NaN
# 79     NaN NaN  NaN         NaN
# 81     NaN NaN  NaN         NaN
# 85     NaN NaN  NaN         NaN
# 88     NaN NaN  NaN         NaN
# 91     NaN NaN  NaN         NaN

# %%
# Condition where 'PIC' column values is not Manda and Ambun
rowsToDropIsNotPIC = df[~(df['PIC'].isin(['Manda', 'Ambun']))].index
rowsToDropIsNotPIC
# Out:
# Index([0, 20, 28, 52, 56, 69, 70, 73, 74, 76, 77, 78, 79, 81, 85, 88, 91], dtype='int64')

# %%
# Delete based on the condition
df = df.drop(index=rowsToDropIsNotPIC)

# Adjust the index in ascending from start until finish
df = df.reset_index(drop=True)

# %%
df.info()
# Successfully adjust
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63 entries, 0 to 62
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   DATE         63 non-null     datetime64[ns]
#  1   DEBIT        0 non-null      object
#  2   CREDIT       63 non-null     object
#  3   RECIPIENT    63 non-null     object
#  4   30           34 non-null     float64
#  5   20           16 non-null     float64
#  6   10           5 non-null      float64
#  7   L            31 non-null     float64
#  8   R            25 non-null     float64
#  9   PIC          63 non-null     object
#  10  Unnamed: 10  6 non-null      object
# dtypes: datetime64[ns](1), float64(5), object(5)
# memory usage: 5.5+ KB

# %%
df.head()
# The first rows that we don't use is successfully deleted
# Out:
#         DATE DEBIT  CREDIT    RECIPIENT   30   20  10    L    R    PIC  \
# 0 2021-07-02   NaN  575000        Saras  2.0  NaN NaN  NaN  3.0  Manda
# 1 2021-07-02   NaN  125000       athina  NaN  1.0 NaN  1.0  NaN  Manda
# 2 2021-07-03   NaN  360000  Mas dhaniar  1.0  NaN NaN  3.0  1.0  Manda
# 3 2021-07-03   NaN   80000       Dimjie  NaN  1.0 NaN  NaN  NaN  Manda
# 4 2021-07-02   NaN  125000    Rhea (IG)  NaN  1.0 NaN  1.0  NaN  Manda
#
#   Unnamed: 10
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
df.tail()
# The last rows that we don't use is successfully deleted
# Out:
#          DATE DEBIT  CREDIT             RECIPIENT   30   20  10    L   R  \
# 58 2021-07-26   NaN   80000                 Linda  NaN  1.0 NaN  NaN NaN
# 59 2021-07-29   NaN  145000             kak wenda  1.0  NaN NaN  1.0 NaN
# 60 2021-07-29   NaN  100000              wan kiki  1.0  NaN NaN  NaN NaN
# 61 2021-07-30   NaN  125000             Tante Iin  NaN  1.0 NaN  1.0 NaN
# 62 2021-07-30   NaN  665000  mas dhika (discount)  7.0  NaN NaN  NaN NaN
#
#       PIC  Unnamed: 10
# 58  Manda          NaN
# 59  Manda  FREE LUMPIA
# 60  Manda  FREE LUMPIA
# 61  Manda          NaN
# 62  Manda          NaN

# %% [markdown]
# #### Rename `30`, `20`, `10`, `L` columns to make it easier to understand

# %%
df[[30, 20, 10, 'L']].head()
# Out:
#     30   20  10    L
# 0  2.0  NaN NaN  NaN
# 1  NaN  1.0 NaN  1.0
# 2  1.0  NaN NaN  3.0
# 3  NaN  1.0 NaN  NaN
# 4  NaN  1.0 NaN  1.0

# %%
# Rename the columns to improve readability
df = df.rename(columns={30:'Shumai 30 Pcs', 20:'Shumai 20 Pcs', 10:'Shumai 10 Pcs', 'L':'Chicken Lumpia 10 Pcs'})

# %%
df[['Shumai 30 Pcs', 'Shumai 20 Pcs', 'Shumai 10 Pcs', 'Chicken Lumpia 10 Pcs']]
# Now, it's getting better
# Out:
#     Shumai 30 Pcs  Shumai 20 Pcs  Shumai 10 Pcs  Chicken Lumpia 10 Pcs
# 0             2.0            NaN            NaN                    NaN
# 1             NaN            1.0            NaN                    1.0
# 2             1.0            NaN            NaN                    3.0
# 3             NaN            1.0            NaN                    NaN
# 4             NaN            1.0            NaN                    1.0
# ..            ...            ...            ...                    ...
# 58            NaN            1.0            NaN                    NaN
# 59            1.0            NaN            NaN                    1.0
# 60            1.0            NaN            NaN                    NaN
# 61            NaN            1.0            NaN                    1.0
# 62            7.0            NaN            NaN                    NaN
#
# [63 rows x 4 columns]

# %%
df.head()
# Out:
#         DATE DEBIT  CREDIT    RECIPIENT  Shumai 30 Pcs  Shumai 20 Pcs  \
# 0 2021-07-02   NaN  575000        Saras            2.0            NaN
# 1 2021-07-02   NaN  125000       athina            NaN            1.0
# 2 2021-07-03   NaN  360000  Mas dhaniar            1.0            NaN
# 3 2021-07-03   NaN   80000       Dimjie            NaN            1.0
# 4 2021-07-02   NaN  125000    Rhea (IG)            NaN            1.0
#
#    Shumai 10 Pcs  Chicken Lumpia 10 Pcs    R    PIC Unnamed: 10
# 0            NaN                    NaN  3.0  Manda         NaN
# 1            NaN                    1.0  NaN  Manda         NaN
# 2            NaN                    3.0  1.0  Manda         NaN
# 3            NaN                    NaN  NaN  Manda         NaN
# 4            NaN                    1.0  NaN  Manda         NaN

# %% [markdown]
# ### Missing Value

# %% [markdown]
# #### Impute missing values of `DATE` column with mode

# %%
df.info();
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63 entries, 0 to 62
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   DATE                   63 non-null     datetime64[ns]
#  1   DEBIT                  0 non-null      object
#  2   CREDIT                 63 non-null     object
#  3   RECIPIENT              63 non-null     object
#  4   Shumai 30 Pcs          34 non-null     float64
#  5   Shumai 20 Pcs          16 non-null     float64
#  6   Shumai 10 Pcs          5 non-null      float64
#  7   Chicken Lumpia 10 Pcs  31 non-null     float64
#  8   R                      25 non-null     float64
#  9   PIC                    63 non-null     object
#  10  Unnamed: 10            6 non-null      object
# dtypes: datetime64[ns](1), float64(5), object(5)
# memory usage: 5.5+ KB
#         DATE DEBIT  CREDIT    RECIPIENT  Shumai 30 Pcs  Shumai 20 Pcs  \
# 0 2021-07-02   NaN  575000        Saras            2.0            NaN
# 1 2021-07-02   NaN  125000       athina            NaN            1.0
# 2 2021-07-03   NaN  360000  Mas dhaniar            1.0            NaN
# 3 2021-07-03   NaN   80000       Dimjie            NaN            1.0
# 4 2021-07-02   NaN  125000    Rhea (IG)            NaN            1.0
#
#    Shumai 10 Pcs  Chicken Lumpia 10 Pcs    R    PIC Unnamed: 10
# 0            NaN                    NaN  3.0  Manda         NaN
# 1            NaN                    1.0  NaN  Manda         NaN
# 2            NaN                    3.0  1.0  Manda         NaN
# 3            NaN                    NaN  NaN  Manda         NaN
# 4            NaN                    1.0  NaN  Manda         NaN

# %%
df['DATE'].mode()
# Out:
# 0   2021-07-02
# 1   2021-07-19
# Name: DATE, dtype: datetime64[ns]

# %%
# Impute missing values of `DATE` column with mode
df['DATE'] = df['DATE'].fillna(df['DATE'].mode()[0])

# %%
df.info();
df.head()
# Successfully fill with mode
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63 entries, 0 to 62
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   DATE                   63 non-null     datetime64[ns]
#  1   DEBIT                  0 non-null      object
#  2   CREDIT                 63 non-null     object
#  3   RECIPIENT              63 non-null     object
#  4   Shumai 30 Pcs          34 non-null     float64
#  5   Shumai 20 Pcs          16 non-null     float64
#  6   Shumai 10 Pcs          5 non-null      float64
#  7   Chicken Lumpia 10 Pcs  31 non-null     float64
#  8   R                      25 non-null     float64
#  9   PIC                    63 non-null     object
#  10  Unnamed: 10            6 non-null      object
# dtypes: datetime64[ns](1), float64(5), object(5)
# memory usage: 5.5+ KB
#         DATE DEBIT  CREDIT    RECIPIENT  Shumai 30 Pcs  Shumai 20 Pcs  \
# 0 2021-07-02   NaN  575000        Saras            2.0            NaN
# 1 2021-07-02   NaN  125000       athina            NaN            1.0
# 2 2021-07-03   NaN  360000  Mas dhaniar            1.0            NaN
# 3 2021-07-03   NaN   80000       Dimjie            NaN            1.0
# 4 2021-07-02   NaN  125000    Rhea (IG)            NaN            1.0
#
#    Shumai 10 Pcs  Chicken Lumpia 10 Pcs    R    PIC Unnamed: 10
# 0            NaN                    NaN  3.0  Manda         NaN
# 1            NaN                    1.0  NaN  Manda         NaN
# 2            NaN                    3.0  1.0  Manda         NaN
# 3            NaN                    NaN  NaN  Manda         NaN
# 4            NaN                    1.0  NaN  Manda         NaN

# %% [markdown]
# ### Inconsistent Data **#2**

# %% [markdown]
# #### Convert `DATE` column into the sum of the month selecting column that we want to use

# %%
# Turn 'DATE' into per month
df['DATE'] = df['DATE'].dt.to_period('M')

# Sum of the month and selecting column that we want to use
df = df.groupby('DATE')[['Shumai 30 Pcs', 'Shumai 20 Pcs', 'Shumai 10 Pcs', 'Chicken Lumpia 10 Pcs']].sum().reset_index()

# %%
df.head()
# Out:
#       DATE  Shumai 30 Pcs  Shumai 20 Pcs  Shumai 10 Pcs  Chicken Lumpia 10 Pcs
# 0  2021-07           50.0           18.0            8.0                   48.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   DATE                   1 non-null      period[M]
#  1   Shumai 30 Pcs          1 non-null      float64
#  2   Shumai 20 Pcs          1 non-null      float64
#  3   Shumai 10 Pcs          1 non-null      float64
#  4   Chicken Lumpia 10 Pcs  1 non-null      float64
# dtypes: float64(4), period[M](1)
# memory usage: 172.0 bytes

# %% [markdown]
# #### Convert the products category sales columns into integer

# %%
# Before convert the datatypes, we must ensure that the columns are not int
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   DATE                   1 non-null      period[M]
#  1   Shumai 30 Pcs          1 non-null      float64
#  2   Shumai 20 Pcs          1 non-null      float64
#  3   Shumai 10 Pcs          1 non-null      float64
#  4   Chicken Lumpia 10 Pcs  1 non-null      float64
# dtypes: float64(4), period[M](1)
# memory usage: 172.0 bytes

# %%
# Convert into int64
df = df.astype({'Shumai 30 Pcs':'int64', 'Shumai 20 Pcs':'int64', 
                'Shumai 10 Pcs':'int64', 'Chicken Lumpia 10 Pcs':'int64'})

# %%
df.info();
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   DATE                   1 non-null      period[M]
#  1   Shumai 30 Pcs          1 non-null      int64
#  2   Shumai 20 Pcs          1 non-null      int64
#  3   Shumai 10 Pcs          1 non-null      int64
#  4   Chicken Lumpia 10 Pcs  1 non-null      int64
# dtypes: int64(4), period[M](1)
# memory usage: 172.0 bytes
#       DATE  Shumai 30 Pcs  Shumai 20 Pcs  Shumai 10 Pcs  Chicken Lumpia 10 Pcs
# 0  2021-07             50             18              8                     48

# %% [markdown]
# ## Export the dataframe into excel files

# %%
# Load datasets and convert it into excel based on month of sales's sheets
df = df.to_excel(r"..\..\data\dataCleaning\JUL21_dataCleaning.xlsx", index=False)

# %%
# selecting columns where column name contains 'Average' string
# df.filter(like='Average')
