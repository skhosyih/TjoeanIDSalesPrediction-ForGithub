# %% [markdown]
# # MAY22 - Data Cleaning

# %% [markdown]
# ## Data Gather

# %% [markdown]
# ### Importing libraries and load the datasets

# %%
from datetime import datetime
import pandas as pd
from openpyxl import Workbook
import numpy as np

# %%
#  Load the datasets
df = pd.read_excel(r"..\..\data\gatherData\MAY22_DimsumTJOEAN.xlsx")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   DATE       11 non-null     datetime64[ns]
#  1   DEBIT      10 non-null     object
#  2   CREDIT     23 non-null     object
#  3   RECIPIENT  19 non-null     object
#  4   30         11 non-null     float64
#  5   20         8 non-null      float64
#  6   10         9 non-null      float64
#  7   L          6 non-null      float64
#  8   R          7 non-null      float64
#  9   G          3 non-null      float64
#  10  PIC        11 non-null     object
# dtypes: datetime64[ns](1), float64(6), object(4)
# memory usage: 3.6+ KB

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Inconsistent Data **#1**

# %% [markdown]
# #### Delete `NaN` rows and the inconsistent rows that we don't use

# %% [markdown]
# ##### Delete `NaN` rows

# %%
df.tail()
# Out:
#    DATE  DEBIT   CREDIT RECIPIENT  30  20  10   L   R   G  PIC
# 35  NaT    NaN  rendang       NaN NaN NaN NaN NaN NaN NaN  NaN
# 36  NaT    NaN      NaN       NaN NaN NaN NaN NaN NaN NaN  NaN
# 37  NaT  Ambun   Shumai       280 NaN NaN NaN NaN NaN NaN  NaN
# 38  NaT    NaN   Lumpia       200 NaN NaN NaN NaN NaN NaN  NaN
# 39  NaT    NaN  Rendang        15 NaN NaN NaN NaN NaN NaN  NaN

# %%
# Rows to drop
rowsToDrop = df[df.isnull().all(axis=1)].index
rowsToDrop
# In a beginning of rows, there are also a 'NaN' values
# Out:
# Index([11, 14, 15, 18, 23, 25, 27, 29, 30, 31, 36], dtype='int64')

# %%
# Delete based on the condition
df = df.drop(index=rowsToDrop)

# %%
df.tail()
# There isn't the all columns have 'NaN' values
# Out:
#    DATE  DEBIT   CREDIT RECIPIENT  30  20  10   L   R   G  PIC
# 34  NaT    NaN   Lumpia        40 NaN NaN NaN NaN NaN NaN  NaN
# 35  NaT    NaN  rendang       NaN NaN NaN NaN NaN NaN NaN  NaN
# 37  NaT  Ambun   Shumai       280 NaN NaN NaN NaN NaN NaN  NaN
# 38  NaT    NaN   Lumpia       200 NaN NaN NaN NaN NaN NaN  NaN
# 39  NaT    NaN  Rendang        15 NaN NaN NaN NaN NaN NaN  NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 29 entries, 0 to 39
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   DATE       11 non-null     datetime64[ns]
#  1   DEBIT      10 non-null     object
#  2   CREDIT     23 non-null     object
#  3   RECIPIENT  19 non-null     object
#  4   30         11 non-null     float64
#  5   20         8 non-null      float64
#  6   10         9 non-null      float64
#  7   L          6 non-null      float64
#  8   R          7 non-null      float64
#  9   G          3 non-null      float64
#  10  PIC        11 non-null     object
# dtypes: datetime64[ns](1), float64(6), object(4)
# memory usage: 2.7+ KB

# %% [markdown]
# ##### Delete the inconsistent rows that we don't use

# %%
df.head()
# Out:
#         DATE DEBIT     CREDIT    RECIPIENT    30    20    10      L      R  \
# 0 2022-05-01   NaN  220201025      April's  43.0  17.0  81.0  104.0  115.0
# 1 2022-05-07   NaN     500000        Ojan    NaN   NaN   NaN    NaN    4.0
# 2 2022-05-08   NaN     165000  Mirtha (IG)   NaN   NaN   1.0    NaN    1.0
# 3 2022-05-10   NaN     100000     mba tora   1.0   NaN   NaN    NaN    NaN
# 4 2022-05-13   NaN     440000     Bu Zulfa   2.0   2.0   3.0    NaN    NaN
#
#      G    PIC
# 0  6.0    NaN
# 1  NaN  Ambun
# 2  NaN  Manda
# 3  NaN  Manda
# 4  NaN  Ambun

# %%
df.tail(6)
# Out:
#    DATE  DEBIT   CREDIT RECIPIENT  30  20  10   L   R   G  PIC
# 33  NaT  Manda   Shumai        70 NaN NaN NaN NaN NaN NaN  NaN
# 34  NaT    NaN   Lumpia        40 NaN NaN NaN NaN NaN NaN  NaN
# 35  NaT    NaN  rendang       NaN NaN NaN NaN NaN NaN NaN  NaN
# 37  NaT  Ambun   Shumai       280 NaN NaN NaN NaN NaN NaN  NaN
# 38  NaT    NaN   Lumpia       200 NaN NaN NaN NaN NaN NaN  NaN
# 39  NaT    NaN  Rendang        15 NaN NaN NaN NaN NaN NaN  NaN

# %%
# Condition where 'PIC' column values is not Manda and Ambun
rowsToDropIsNotPIC = df[~(df['PIC'].isin(['Manda', 'Ambun']))].index
rowsToDropIsNotPIC
# Out:
# Index([0, 12, 13, 16, 17, 19, 20, 21, 22, 24, 26, 28, 32, 33, 34, 35, 37, 38,
#        39],
#       dtype='int64')

# %%
# Delete based on the condition
df = df.drop(index=rowsToDropIsNotPIC)

# Adjust the index in ascending from start until finish
df = df.reset_index(drop=True)

# %%
df.info()
# Successfully adjust
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   DATE       10 non-null     datetime64[ns]
#  1   DEBIT      0 non-null      object
#  2   CREDIT     10 non-null     object
#  3   RECIPIENT  10 non-null     object
#  4   30         6 non-null      float64
#  5   20         3 non-null      float64
#  6   10         4 non-null      float64
#  7   L          2 non-null      float64
#  8   R          4 non-null      float64
#  9   G          0 non-null      float64
#  10  PIC        10 non-null     object
# dtypes: datetime64[ns](1), float64(6), object(4)
# memory usage: 1012.0+ bytes

# %%
df.head()
# The first rows that we don't use is successfully deleted
# Out:
#         DATE DEBIT  CREDIT    RECIPIENT   30   20   10    L    R   G    PIC
# 0 2022-05-07   NaN  500000        Ojan   NaN  NaN  NaN  NaN  4.0 NaN  Ambun
# 1 2022-05-08   NaN  165000  Mirtha (IG)  NaN  NaN  1.0  NaN  1.0 NaN  Manda
# 2 2022-05-10   NaN  100000     mba tora  1.0  NaN  NaN  NaN  NaN NaN  Manda
# 3 2022-05-13   NaN  440000     Bu Zulfa  2.0  2.0  3.0  NaN  NaN NaN  Ambun
# 4 2022-05-20   NaN  315000    Kak lhiya  1.0  1.0  NaN  3.0  NaN NaN  Manda

# %%
df.tail()
# The last rows that we don't use is successfully deleted
# Out:
#         DATE DEBIT   CREDIT           RECIPIENT   30   20   10    L    R   G  \
# 5 2022-05-17   NaN   300000             Bu lusy  3.0  NaN  NaN  NaN  NaN NaN
# 6 2022-05-12   NaN   100000            Mas diko  1.0  NaN  NaN  NaN  NaN NaN
# 7 2022-05-19   NaN   250000          Tante Legi  NaN  NaN  NaN  NaN  2.0 NaN
# 8 2022-05-24   NaN   210000            mba ilen  NaN  NaN  1.0  1.0  1.0 NaN
# 9 2022-05-30   NaN  1235000  Aldhira [reseller]  8.0  5.0  5.0  NaN  NaN NaN
#
#      PIC
# 5  Manda
# 6  Manda
# 7  Ambun
# 8  Manda
# 9  Manda

# %% [markdown]
# #### Rename `30`, `20`, `10`, `L` columns to make it easier to understand

# %%
df[[30, 20, 10, 'L']].head()
# Out:
#     30   20   10    L
# 0  NaN  NaN  NaN  NaN
# 1  NaN  NaN  1.0  NaN
# 2  1.0  NaN  NaN  NaN
# 3  2.0  2.0  3.0  NaN
# 4  1.0  1.0  NaN  3.0

# %%
# Rename the columns to improve readability
df = df.rename(columns={30:'Shumai 30 Pcs', 20:'Shumai 20 Pcs', 10:'Shumai 10 Pcs', 'L':'Chicken Lumpia 10 Pcs'})

# %%
df[['Shumai 30 Pcs', 'Shumai 20 Pcs', 'Shumai 10 Pcs', 'Chicken Lumpia 10 Pcs']]
# Now, it's getting better
# Out:
#    Shumai 30 Pcs  Shumai 20 Pcs  Shumai 10 Pcs  Chicken Lumpia 10 Pcs
# 0            NaN            NaN            NaN                    NaN
# 1            NaN            NaN            1.0                    NaN
# 2            1.0            NaN            NaN                    NaN
# 3            2.0            2.0            3.0                    NaN
# 4            1.0            1.0            NaN                    3.0
# 5            3.0            NaN            NaN                    NaN
# 6            1.0            NaN            NaN                    NaN
# 7            NaN            NaN            NaN                    NaN
# 8            NaN            NaN            1.0                    1.0
# 9            8.0            5.0            5.0                    NaN

# %%
df.head()
# Out:
#         DATE DEBIT  CREDIT    RECIPIENT  Shumai 30 Pcs  Shumai 20 Pcs  \
# 0 2022-05-07   NaN  500000        Ojan             NaN            NaN
# 1 2022-05-08   NaN  165000  Mirtha (IG)            NaN            NaN
# 2 2022-05-10   NaN  100000     mba tora            1.0            NaN
# 3 2022-05-13   NaN  440000     Bu Zulfa            2.0            2.0
# 4 2022-05-20   NaN  315000    Kak lhiya            1.0            1.0
#
#    Shumai 10 Pcs  Chicken Lumpia 10 Pcs    R   G    PIC
# 0            NaN                    NaN  4.0 NaN  Ambun
# 1            1.0                    NaN  1.0 NaN  Manda
# 2            NaN                    NaN  NaN NaN  Manda
# 3            3.0                    NaN  NaN NaN  Ambun
# 4            NaN                    3.0  NaN NaN  Manda

# %% [markdown]
# ### Missing Value

# %% [markdown]
# #### Impute missing values of `DATE` column with mode

# %%
df.info();
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   DATE                   10 non-null     datetime64[ns]
#  1   DEBIT                  0 non-null      object
#  2   CREDIT                 10 non-null     object
#  3   RECIPIENT              10 non-null     object
#  4   Shumai 30 Pcs          6 non-null      float64
#  5   Shumai 20 Pcs          3 non-null      float64
#  6   Shumai 10 Pcs          4 non-null      float64
#  7   Chicken Lumpia 10 Pcs  2 non-null      float64
#  8   R                      4 non-null      float64
#  9   G                      0 non-null      float64
#  10  PIC                    10 non-null     object
# dtypes: datetime64[ns](1), float64(6), object(4)
# memory usage: 1012.0+ bytes
#         DATE DEBIT  CREDIT    RECIPIENT  Shumai 30 Pcs  Shumai 20 Pcs  \
# 0 2022-05-07   NaN  500000        Ojan             NaN            NaN
# 1 2022-05-08   NaN  165000  Mirtha (IG)            NaN            NaN
# 2 2022-05-10   NaN  100000     mba tora            1.0            NaN
# 3 2022-05-13   NaN  440000     Bu Zulfa            2.0            2.0
# 4 2022-05-20   NaN  315000    Kak lhiya            1.0            1.0
#
#    Shumai 10 Pcs  Chicken Lumpia 10 Pcs    R   G    PIC
# 0            NaN                    NaN  4.0 NaN  Ambun
# 1            1.0                    NaN  1.0 NaN  Manda
# 2            NaN                    NaN  NaN NaN  Manda
# 3            3.0                    NaN  NaN NaN  Ambun
# 4            NaN                    3.0  NaN NaN  Manda

# %%
df['DATE'].mode()
# Out:
# 0   2022-05-07
# 1   2022-05-08
# 2   2022-05-10
# 3   2022-05-12
# 4   2022-05-13
# 5   2022-05-17
# 6   2022-05-19
# 7   2022-05-20
# 8   2022-05-24
# 9   2022-05-30
# Name: DATE, dtype: datetime64[ns]

# %%
# Impute missing values of `DATE` column with mode
df['DATE'] = df['DATE'].fillna(df['DATE'].mode()[0])

# %%
df.info();
df.head()
# Successfully fill with mode
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   DATE                   10 non-null     datetime64[ns]
#  1   DEBIT                  0 non-null      object
#  2   CREDIT                 10 non-null     object
#  3   RECIPIENT              10 non-null     object
#  4   Shumai 30 Pcs          6 non-null      float64
#  5   Shumai 20 Pcs          3 non-null      float64
#  6   Shumai 10 Pcs          4 non-null      float64
#  7   Chicken Lumpia 10 Pcs  2 non-null      float64
#  8   R                      4 non-null      float64
#  9   G                      0 non-null      float64
#  10  PIC                    10 non-null     object
# dtypes: datetime64[ns](1), float64(6), object(4)
# memory usage: 1012.0+ bytes
#         DATE DEBIT  CREDIT    RECIPIENT  Shumai 30 Pcs  Shumai 20 Pcs  \
# 0 2022-05-07   NaN  500000        Ojan             NaN            NaN
# 1 2022-05-08   NaN  165000  Mirtha (IG)            NaN            NaN
# 2 2022-05-10   NaN  100000     mba tora            1.0            NaN
# 3 2022-05-13   NaN  440000     Bu Zulfa            2.0            2.0
# 4 2022-05-20   NaN  315000    Kak lhiya            1.0            1.0
#
#    Shumai 10 Pcs  Chicken Lumpia 10 Pcs    R   G    PIC
# 0            NaN                    NaN  4.0 NaN  Ambun
# 1            1.0                    NaN  1.0 NaN  Manda
# 2            NaN                    NaN  NaN NaN  Manda
# 3            3.0                    NaN  NaN NaN  Ambun
# 4            NaN                    3.0  NaN NaN  Manda

# %% [markdown]
# ### Inconsistent Data **#2**

# %% [markdown]
# #### Convert `DATE` column into the sum of the month selecting column that we want to use

# %%
# Turn 'DATE' into per month
df['DATE'] = df['DATE'].dt.to_period('M')

# Sum of the month and selecting column that we want to use
df = df.groupby('DATE')[['Shumai 30 Pcs', 'Shumai 20 Pcs', 'Shumai 10 Pcs', 'Chicken Lumpia 10 Pcs']].sum().reset_index()

# %%
df.head()
# Out:
#       DATE  Shumai 30 Pcs  Shumai 20 Pcs  Shumai 10 Pcs  Chicken Lumpia 10 Pcs
# 0  2022-05           16.0            8.0           10.0                    4.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   DATE                   1 non-null      period[M]
#  1   Shumai 30 Pcs          1 non-null      float64
#  2   Shumai 20 Pcs          1 non-null      float64
#  3   Shumai 10 Pcs          1 non-null      float64
#  4   Chicken Lumpia 10 Pcs  1 non-null      float64
# dtypes: float64(4), period[M](1)
# memory usage: 172.0 bytes

# %% [markdown]
# #### Convert the products category sales columns into integer

# %%
# Before convert the datatypes, we must ensure that the columns are not int
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   DATE                   1 non-null      period[M]
#  1   Shumai 30 Pcs          1 non-null      float64
#  2   Shumai 20 Pcs          1 non-null      float64
#  3   Shumai 10 Pcs          1 non-null      float64
#  4   Chicken Lumpia 10 Pcs  1 non-null      float64
# dtypes: float64(4), period[M](1)
# memory usage: 172.0 bytes

# %%
# Convert into int64
df = df.astype({'Shumai 30 Pcs':'int64', 'Shumai 20 Pcs':'int64', 
                'Shumai 10 Pcs':'int64', 'Chicken Lumpia 10 Pcs':'int64'})

# %%
df.info();
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   DATE                   1 non-null      period[M]
#  1   Shumai 30 Pcs          1 non-null      int64
#  2   Shumai 20 Pcs          1 non-null      int64
#  3   Shumai 10 Pcs          1 non-null      int64
#  4   Chicken Lumpia 10 Pcs  1 non-null      int64
# dtypes: int64(4), period[M](1)
# memory usage: 172.0 bytes
#       DATE  Shumai 30 Pcs  Shumai 20 Pcs  Shumai 10 Pcs  Chicken Lumpia 10 Pcs
# 0  2022-05             16              8             10                      4

# %% [markdown]
# ## Export the dataframe into excel files

# %%
# Load datasets and convert it into excel based on month of sales's sheets
df = df.to_excel(r"..\..\data\dataCleaning\MAY22_dataCleaning.xlsx", index=False)

# %%
# selecting columns where column name contains 'Average' string
# df.filter(like='Average')
