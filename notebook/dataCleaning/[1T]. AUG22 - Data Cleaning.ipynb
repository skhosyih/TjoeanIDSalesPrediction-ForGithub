# %% [markdown]
# # AUG22 - Data Cleaning

# %% [markdown]
# ## Data Gather

# %% [markdown]
# ### Importing libraries and load the datasets

# %%
from datetime import datetime
import pandas as pd
from openpyxl import Workbook
import numpy as np

# %%
#  Load the datasets
df = pd.read_excel(r"..\..\data\gatherData\AUG22_DimsumTJOEAN.xlsx")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   DATE       18 non-null     datetime64[ns]
#  1   DEBIT      10 non-null     object
#  2   CREDIT     29 non-null     object
#  3   RECIPIENT  24 non-null     object
#  4   30         13 non-null     float64
#  5   20         8 non-null      float64
#  6   10         8 non-null      float64
#  7   L          13 non-null     float64
#  8   R          3 non-null      float64
#  9   G          8 non-null      float64
#  10  CO         5 non-null      float64
#  11  M          3 non-null      float64
#  12  PIC        18 non-null     object
# dtypes: datetime64[ns](1), float64(8), object(4)
# memory usage: 4.7+ KB

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Inconsistent Data **#1**

# %% [markdown]
# #### Delete `NaN` rows and the inconsistent rows that we don't use

# %% [markdown]
# ##### Delete `NaN` rows

# %%
df.tail()
# Out:
#    DATE  DEBIT                               CREDIT RECIPIENT  30  20  10   L  \
# 40  NaT  Manda  [udah aku settle ke utang semua ya]       NaN NaN NaN NaN NaN
# 41  NaT    NaN                                  NaN       NaN NaN NaN NaN NaN
# 42  NaT  Ambun                               Shumai       280 NaN NaN NaN NaN
# 43  NaT    NaN                               Lumpia       200 NaN NaN NaN NaN
# 44  NaT    NaN                              Rendang        15 NaN NaN NaN NaN
#
#      R   G  CO   M  PIC
# 40 NaN NaN NaN NaN  NaN
# 41 NaN NaN NaN NaN  NaN
# 42 NaN NaN NaN NaN  NaN
# 43 NaN NaN NaN NaN  NaN
# 44 NaN NaN NaN NaN  NaN

# %%
# Rows to drop
rowsToDrop = df[df.isnull().all(axis=1)].index
rowsToDrop
# In a beginning of rows, there are also a 'NaN' values
# Out:
# Index([18, 21, 22, 25, 32, 34, 36, 37, 38, 41], dtype='int64')

# %%
# Delete based on the condition
df = df.drop(index=rowsToDrop)

# %%
df.tail()
# There isn't the all columns have 'NaN' values
# Out:
#    DATE    DEBIT                               CREDIT RECIPIENT  30  20  10  \
# 39  NaT  HAMPERS                                  NaN       NaN NaN NaN NaN
# 40  NaT    Manda  [udah aku settle ke utang semua ya]       NaN NaN NaN NaN
# 42  NaT    Ambun                               Shumai       280 NaN NaN NaN
# 43  NaT      NaN                               Lumpia       200 NaN NaN NaN
# 44  NaT      NaN                              Rendang        15 NaN NaN NaN
#
#      L   R   G  CO   M  PIC
# 39 NaN NaN NaN NaN NaN  NaN
# 40 NaN NaN NaN NaN NaN  NaN
# 42 NaN NaN NaN NaN NaN  NaN
# 43 NaN NaN NaN NaN NaN  NaN
# 44 NaN NaN NaN NaN NaN  NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 35 entries, 0 to 44
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   DATE       18 non-null     datetime64[ns]
#  1   DEBIT      10 non-null     object
#  2   CREDIT     29 non-null     object
#  3   RECIPIENT  24 non-null     object
#  4   30         13 non-null     float64
#  5   20         8 non-null      float64
#  6   10         8 non-null      float64
#  7   L          13 non-null     float64
#  8   R          3 non-null      float64
#  9   G          8 non-null      float64
#  10  CO         5 non-null      float64
#  11  M          3 non-null      float64
#  12  PIC        18 non-null     object
# dtypes: datetime64[ns](1), float64(8), object(4)
# memory usage: 3.8+ KB

# %% [markdown]
# ##### Delete the inconsistent rows that we don't use

# %%
df.head()
# Out:
#         DATE DEBIT     CREDIT RECIPIENT    30   20   10    L    R    G   CO  \
# 0 2022-08-01   NaN  233709025    July's  19.0  2.0  1.0  2.0  7.0  0.0  NaN
# 1 2022-08-11   NaN      85000      Zaza   NaN  NaN  NaN  1.0  NaN  NaN  1.0
# 2 2022-08-12   NaN      85000      Dito   NaN  NaN  NaN  1.0  NaN  1.0  NaN
# 3 2022-08-20   NaN      65000     Riksa   NaN  NaN  NaN  1.0  NaN  NaN  NaN
# 4 2022-08-08   NaN     320000     dhani   NaN  2.0  NaN  NaN  NaN  4.0  NaN
#
#      M    PIC
# 0  NaN    NaN
# 1  NaN  Manda
# 2  NaN  Manda
# 3  1.0  Manda
# 4  NaN  Manda

# %%
df.tail(6)
# Out:
#    DATE    DEBIT                               CREDIT RECIPIENT     30    20  \
# 35  NaT  PIUTANG                                  NaN       600  450.0  80.0
# 39  NaT  HAMPERS                                  NaN       NaN    NaN   NaN
# 40  NaT    Manda  [udah aku settle ke utang semua ya]       NaN    NaN   NaN
# 42  NaT    Ambun                               Shumai       280    NaN   NaN
# 43  NaT      NaN                               Lumpia       200    NaN   NaN
# 44  NaT      NaN                              Rendang        15    NaN   NaN
#
#       10   L   R   G  CO   M  PIC
# 35  70.0 NaN NaN NaN NaN NaN  NaN
# 39   NaN NaN NaN NaN NaN NaN  NaN
# 40   NaN NaN NaN NaN NaN NaN  NaN
# 42   NaN NaN NaN NaN NaN NaN  NaN
# 43   NaN NaN NaN NaN NaN NaN  NaN
# 44   NaN NaN NaN NaN NaN NaN  NaN

# %%
# Condition where 'PIC' column values is not Manda and Ambun
rowsToDropIsNotPIC = df[~(df['PIC'].isin(['Manda', 'Ambun']))].index
rowsToDropIsNotPIC
# Out:
# Index([0, 19, 20, 23, 24, 26, 27, 28, 29, 30, 31, 33, 35, 39, 40, 42, 43, 44], dtype='int64')

# %%
# Delete based on the condition
df = df.drop(index=rowsToDropIsNotPIC)

# Adjust the index in ascending from start until finish
df = df.reset_index(drop=True)

# %%
df.info()
# Successfully adjust
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   DATE       17 non-null     datetime64[ns]
#  1   DEBIT      0 non-null      object
#  2   CREDIT     17 non-null     object
#  3   RECIPIENT  17 non-null     object
#  4   30         8 non-null      float64
#  5   20         3 non-null      float64
#  6   10         3 non-null      float64
#  7   L          9 non-null      float64
#  8   R          0 non-null      float64
#  9   G          5 non-null      float64
#  10  CO         3 non-null      float64
#  11  M          1 non-null      float64
#  12  PIC        17 non-null     object
# dtypes: datetime64[ns](1), float64(8), object(4)
# memory usage: 1.9+ KB

# %%
df.head()
# The first rows that we don't use is successfully deleted
# Out:
#         DATE DEBIT  CREDIT RECIPIENT   30   20  10    L   R    G   CO    M  \
# 0 2022-08-11   NaN   85000      Zaza  NaN  NaN NaN  1.0 NaN  NaN  1.0  NaN
# 1 2022-08-12   NaN   85000      Dito  NaN  NaN NaN  1.0 NaN  1.0  NaN  NaN
# 2 2022-08-20   NaN   65000     Riksa  NaN  NaN NaN  1.0 NaN  NaN  NaN  1.0
# 3 2022-08-08   NaN  320000     dhani  NaN  2.0 NaN  NaN NaN  4.0  NaN  NaN
# 4 2022-08-03   NaN  100000  mas diko  1.0  NaN NaN  NaN NaN  NaN  NaN  NaN
#
#      PIC
# 0  Manda
# 1  Manda
# 2  Manda
# 3  Manda
# 4  Manda

# %%
df.tail()
# The last rows that we don't use is successfully deleted
# Out:
#          DATE DEBIT  CREDIT   RECIPIENT   30  20   10    L   R    G   CO   M  \
# 12 2022-08-07   NaN   85000        Dito  NaN NaN  NaN  1.0 NaN  1.0  NaN NaN
# 13 2022-08-31   NaN   45000     Miranti  NaN NaN  NaN  1.0 NaN  NaN  NaN NaN
# 14 2022-08-24   NaN  140000        dito  1.0 NaN  NaN  NaN NaN  1.0  NaN NaN
# 15 2022-08-22   NaN   85000  mba riksa   NaN NaN  1.0  1.0 NaN  NaN  NaN NaN
# 16 2022-08-11   NaN  250000        dito  NaN NaN  1.0  2.0 NaN  2.0  1.0 NaN
#
#       PIC
# 12  Manda
# 13  Manda
# 14  Manda
# 15  Manda
# 16  Manda

# %% [markdown]
# #### Rename `30`, `20`, `10`, `L` columns to make it easier to understand

# %%
df[[30, 20, 10, 'L']].head()
# Out:
#     30   20  10    L
# 0  NaN  NaN NaN  1.0
# 1  NaN  NaN NaN  1.0
# 2  NaN  NaN NaN  1.0
# 3  NaN  2.0 NaN  NaN
# 4  1.0  NaN NaN  NaN

# %%
# Rename the columns to improve readability
df = df.rename(columns={30:'Shumai 30 Pcs', 20:'Shumai 20 Pcs', 10:'Shumai 10 Pcs', 'L':'Chicken Lumpia 10 Pcs'})

# %%
df[['Shumai 30 Pcs', 'Shumai 20 Pcs', 'Shumai 10 Pcs', 'Chicken Lumpia 10 Pcs']]
# Now, it's getting better
# Out:
#     Shumai 30 Pcs  Shumai 20 Pcs  Shumai 10 Pcs  Chicken Lumpia 10 Pcs
# 0             NaN            NaN            NaN                    1.0
# 1             NaN            NaN            NaN                    1.0
# 2             NaN            NaN            NaN                    1.0
# 3             NaN            2.0            NaN                    NaN
# 4             1.0            NaN            NaN                    NaN
# 5             1.0            NaN            NaN                    NaN
# 6             2.0            NaN            NaN                    1.0
# 7             2.0            4.0            NaN                    2.0
# 8             5.0            2.0            NaN                    NaN
# 9             NaN            NaN            1.0                    NaN
# 10            2.0            NaN            NaN                    NaN
# 11            1.0            NaN            NaN                    NaN
# 12            NaN            NaN            NaN                    1.0
# 13            NaN            NaN            NaN                    1.0
# 14            1.0            NaN            NaN                    NaN
# 15            NaN            NaN            1.0                    1.0
# 16            NaN            NaN            1.0                    2.0

# %%
df.head()
# Out:
#         DATE DEBIT  CREDIT RECIPIENT  Shumai 30 Pcs  Shumai 20 Pcs  \
# 0 2022-08-11   NaN   85000      Zaza            NaN            NaN
# 1 2022-08-12   NaN   85000      Dito            NaN            NaN
# 2 2022-08-20   NaN   65000     Riksa            NaN            NaN
# 3 2022-08-08   NaN  320000     dhani            NaN            2.0
# 4 2022-08-03   NaN  100000  mas diko            1.0            NaN
#
#    Shumai 10 Pcs  Chicken Lumpia 10 Pcs   R    G   CO    M    PIC
# 0            NaN                    1.0 NaN  NaN  1.0  NaN  Manda
# 1            NaN                    1.0 NaN  1.0  NaN  NaN  Manda
# 2            NaN                    1.0 NaN  NaN  NaN  1.0  Manda
# 3            NaN                    NaN NaN  4.0  NaN  NaN  Manda
# 4            NaN                    NaN NaN  NaN  NaN  NaN  Manda

# %% [markdown]
# ### Missing Value

# %% [markdown]
# #### Impute missing values of `DATE` column with mode

# %%
df.info();
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   DATE                   17 non-null     datetime64[ns]
#  1   DEBIT                  0 non-null      object
#  2   CREDIT                 17 non-null     object
#  3   RECIPIENT              17 non-null     object
#  4   Shumai 30 Pcs          8 non-null      float64
#  5   Shumai 20 Pcs          3 non-null      float64
#  6   Shumai 10 Pcs          3 non-null      float64
#  7   Chicken Lumpia 10 Pcs  9 non-null      float64
#  8   R                      0 non-null      float64
#  9   G                      5 non-null      float64
#  10  CO                     3 non-null      float64
#  11  M                      1 non-null      float64
#  12  PIC                    17 non-null     object
# dtypes: datetime64[ns](1), float64(8), object(4)
# memory usage: 1.9+ KB
#         DATE DEBIT  CREDIT RECIPIENT  Shumai 30 Pcs  Shumai 20 Pcs  \
# 0 2022-08-11   NaN   85000      Zaza            NaN            NaN
# 1 2022-08-12   NaN   85000      Dito            NaN            NaN
# 2 2022-08-20   NaN   65000     Riksa            NaN            NaN
# 3 2022-08-08   NaN  320000     dhani            NaN            2.0
# 4 2022-08-03   NaN  100000  mas diko            1.0            NaN
#
#    Shumai 10 Pcs  Chicken Lumpia 10 Pcs   R    G   CO    M    PIC
# 0            NaN                    1.0 NaN  NaN  1.0  NaN  Manda
# 1            NaN                    1.0 NaN  1.0  NaN  NaN  Manda
# 2            NaN                    1.0 NaN  NaN  NaN  1.0  Manda
# 3            NaN                    NaN NaN  4.0  NaN  NaN  Manda
# 4            NaN                    NaN NaN  NaN  NaN  NaN  Manda

# %%
df['DATE'].mode()
# Out:
# 0   2022-08-03
# Name: DATE, dtype: datetime64[ns]

# %%
# Impute missing values of `DATE` column with mode
df['DATE'] = df['DATE'].fillna(df['DATE'].mode()[0])

# %%
df.info();
df.head()
# Successfully fill with mode
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   DATE                   17 non-null     datetime64[ns]
#  1   DEBIT                  0 non-null      object
#  2   CREDIT                 17 non-null     object
#  3   RECIPIENT              17 non-null     object
#  4   Shumai 30 Pcs          8 non-null      float64
#  5   Shumai 20 Pcs          3 non-null      float64
#  6   Shumai 10 Pcs          3 non-null      float64
#  7   Chicken Lumpia 10 Pcs  9 non-null      float64
#  8   R                      0 non-null      float64
#  9   G                      5 non-null      float64
#  10  CO                     3 non-null      float64
#  11  M                      1 non-null      float64
#  12  PIC                    17 non-null     object
# dtypes: datetime64[ns](1), float64(8), object(4)
# memory usage: 1.9+ KB
#         DATE DEBIT  CREDIT RECIPIENT  Shumai 30 Pcs  Shumai 20 Pcs  \
# 0 2022-08-11   NaN   85000      Zaza            NaN            NaN
# 1 2022-08-12   NaN   85000      Dito            NaN            NaN
# 2 2022-08-20   NaN   65000     Riksa            NaN            NaN
# 3 2022-08-08   NaN  320000     dhani            NaN            2.0
# 4 2022-08-03   NaN  100000  mas diko            1.0            NaN
#
#    Shumai 10 Pcs  Chicken Lumpia 10 Pcs   R    G   CO    M    PIC
# 0            NaN                    1.0 NaN  NaN  1.0  NaN  Manda
# 1            NaN                    1.0 NaN  1.0  NaN  NaN  Manda
# 2            NaN                    1.0 NaN  NaN  NaN  1.0  Manda
# 3            NaN                    NaN NaN  4.0  NaN  NaN  Manda
# 4            NaN                    NaN NaN  NaN  NaN  NaN  Manda

# %% [markdown]
# ### Inconsistent Data **#2**

# %% [markdown]
# #### Convert `DATE` column into the sum of the month selecting column that we want to use

# %%
# Turn 'DATE' into per month
df['DATE'] = df['DATE'].dt.to_period('M')

# Sum of the month and selecting column that we want to use
df = df.groupby('DATE')[['Shumai 30 Pcs', 'Shumai 20 Pcs', 'Shumai 10 Pcs', 'Chicken Lumpia 10 Pcs']].sum().reset_index()

# %%
df.head()
# Out:
#       DATE  Shumai 30 Pcs  Shumai 20 Pcs  Shumai 10 Pcs  Chicken Lumpia 10 Pcs
# 0  2022-08           15.0            8.0            3.0                   11.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   DATE                   1 non-null      period[M]
#  1   Shumai 30 Pcs          1 non-null      float64
#  2   Shumai 20 Pcs          1 non-null      float64
#  3   Shumai 10 Pcs          1 non-null      float64
#  4   Chicken Lumpia 10 Pcs  1 non-null      float64
# dtypes: float64(4), period[M](1)
# memory usage: 172.0 bytes

# %% [markdown]
# #### Convert the products category sales columns into integer

# %%
# Before convert the datatypes, we must ensure that the columns are not int
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   DATE                   1 non-null      period[M]
#  1   Shumai 30 Pcs          1 non-null      float64
#  2   Shumai 20 Pcs          1 non-null      float64
#  3   Shumai 10 Pcs          1 non-null      float64
#  4   Chicken Lumpia 10 Pcs  1 non-null      float64
# dtypes: float64(4), period[M](1)
# memory usage: 172.0 bytes

# %%
# Convert into int64
df = df.astype({'Shumai 30 Pcs':'int64', 'Shumai 20 Pcs':'int64', 
                'Shumai 10 Pcs':'int64', 'Chicken Lumpia 10 Pcs':'int64'})

# %%
df.info();
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   DATE                   1 non-null      period[M]
#  1   Shumai 30 Pcs          1 non-null      int64
#  2   Shumai 20 Pcs          1 non-null      int64
#  3   Shumai 10 Pcs          1 non-null      int64
#  4   Chicken Lumpia 10 Pcs  1 non-null      int64
# dtypes: int64(4), period[M](1)
# memory usage: 172.0 bytes
#       DATE  Shumai 30 Pcs  Shumai 20 Pcs  Shumai 10 Pcs  Chicken Lumpia 10 Pcs
# 0  2022-08             15              8              3                     11

# %% [markdown]
# ## Export the dataframe into excel files

# %%
# Load datasets and convert it into excel based on month of sales's sheets
df = df.to_excel(r"..\..\data\dataCleaning\AUG22_dataCleaning.xlsx", index=False)

# %%
# selecting columns where column name contains 'Average' string
# df.filter(like='Average')
