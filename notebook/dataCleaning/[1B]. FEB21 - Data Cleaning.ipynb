# %% [markdown]
# # FEB21 - Data Cleaning

# %% [markdown]
# ## Data Gather

# %% [markdown]
# ### Importing libraries and load the datasets

# %%
from datetime import datetime
import pandas as pd
from openpyxl import Workbook
import numpy as np

# %%
#  Load the datasets
df = pd.read_excel(r"..\..\data\gatherData\FEB21_DimsumTJOEAN.xlsx")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 141 entries, 0 to 140
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   DATE         126 non-null    object
#  1   DEBIT        3 non-null      object
#  2   CREDIT       133 non-null    object
#  3   RECIPIENT    133 non-null    object
#  4   30           82 non-null     float64
#  5   20           35 non-null     float64
#  6   10           30 non-null     float64
#  7   L            36 non-null     float64
#  8   PIC          132 non-null    object
#  9   Unnamed: 9   1 non-null      float64
#  10  Unnamed: 10  0 non-null      float64
# dtypes: float64(6), object(5)
# memory usage: 12.2+ KB

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Inconsistent Data **#1**

# %% [markdown]
# #### Delete `NaN` rows and the inconsistent rows that we don't use

# %% [markdown]
# ##### Delete `NaN` rows

# %%
df.tail()
# Out:
#     DATE                DEBIT  CREDIT RECIPIENT      30      20     10      L  \
# 136  NaN              #TJOEAN     NaN       NaN     NaN     NaN    NaN    NaN
# 137  NaN                  NaN     NaN       NaN     NaN     NaN    NaN    NaN
# 138  NaN                  NaN     NaN       NaN  5880.0  1340.0  660.0  460.0
# 139  NaN  Utang Dimsum 100pcs     NaN       NaN     NaN     NaN    NaN    NaN
# 140  NaN     Promotion Budget  Indira     30pcs  8340.0     NaN    NaN    NaN
#
#      PIC  Unnamed: 9  Unnamed: 10
# 136  NaN         NaN          NaN
# 137  NaN         NaN          NaN
# 138  NaN         NaN          NaN
# 139  NaN         NaN          NaN
# 140  NaN         NaN          NaN

# %%
# Rows to drop
rowsToDrop = df[df.isnull().all(axis=1)].index
rowsToDrop
# In a beginning of rows, there are also a 'NaN' values
# Out:
# Index([1, 133, 134, 137], dtype='int64')

# %%
# Delete based on the condition
df = df.drop(index=rowsToDrop)

# %%
df.tail()
# There isn't the all columns have 'NaN' values
# Out:
#     DATE                DEBIT    CREDIT RECIPIENT      30      20     10  \
# 135  NaN                  NaN  29525000       NaN   104.0    35.0   31.0
# 136  NaN              #TJOEAN       NaN       NaN     NaN     NaN    NaN
# 138  NaN                  NaN       NaN       NaN  5880.0  1340.0  660.0
# 139  NaN  Utang Dimsum 100pcs       NaN       NaN     NaN     NaN    NaN
# 140  NaN     Promotion Budget    Indira     30pcs  8340.0     NaN    NaN
#
#          L    PIC  Unnamed: 9  Unnamed: 10
# 135   59.0  TOTAL         NaN          NaN
# 136    NaN    NaN         NaN          NaN
# 138  460.0    NaN         NaN          NaN
# 139    NaN    NaN         NaN          NaN
# 140    NaN    NaN         NaN          NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 137 entries, 0 to 140
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   DATE         126 non-null    object
#  1   DEBIT        3 non-null      object
#  2   CREDIT       133 non-null    object
#  3   RECIPIENT    133 non-null    object
#  4   30           82 non-null     float64
#  5   20           35 non-null     float64
#  6   10           30 non-null     float64
#  7   L            36 non-null     float64
#  8   PIC          132 non-null    object
#  9   Unnamed: 9   1 non-null      float64
#  10  Unnamed: 10  0 non-null      float64
# dtypes: float64(6), object(5)
# memory usage: 12.8+ KB

# %% [markdown]
# ##### Delete the inconsistent rows that we don't use

# %%
df.head()
# Out:
#                   DATE DEBIT    CREDIT                RECIPIENT    30    20  \
# 0                  NaN   NaN  13010000                January's  92.0  32.0
# 2  2021-02-01 00:00:00   NaN    100000  Kak fira (pack of 30's)   1.0   NaN
# 3  2021-02-02 00:00:00   NaN     80000      Fira (pack of 20's)   NaN   1.0
# 4  2021-02-02 00:00:00   NaN     80000      Audi (pack of 20's)   NaN   1.0
# 5                  NaN   NaN     40000                    Santi   NaN   NaN
#
#      10   L    PIC  Unnamed: 9  Unnamed: 10
# 0  35.0 NaN    NaN         NaN          NaN
# 2   NaN NaN  Ambun         0.0          NaN
# 3   NaN NaN  Ambun         NaN          NaN
# 4   NaN NaN  Manda         NaN          NaN
# 5   1.0 NaN  Manda         NaN          NaN

# %%
df.tail(6)
# Out:
#                     DATE                DEBIT    CREDIT   RECIPIENT      30  \
# 132  2021-02-28 00:00:00                  NaN    200000  Tante Rini     1.0
# 135                  NaN                  NaN  29525000         NaN   104.0
# 136                  NaN              #TJOEAN       NaN         NaN     NaN
# 138                  NaN                  NaN       NaN         NaN  5880.0
# 139                  NaN  Utang Dimsum 100pcs       NaN         NaN     NaN
# 140                  NaN     Promotion Budget    Indira       30pcs  8340.0
#
#          20     10      L    PIC  Unnamed: 9  Unnamed: 10
# 132     1.0    1.0    NaN  Manda         NaN          NaN
# 135    35.0   31.0   59.0  TOTAL         NaN          NaN
# 136     NaN    NaN    NaN    NaN         NaN          NaN
# 138  1340.0  660.0  460.0    NaN         NaN          NaN
# 139     NaN    NaN    NaN    NaN         NaN          NaN
# 140     NaN    NaN    NaN    NaN         NaN          NaN

# %%
# Condition where 'PIC' column values is not Manda and Ambun
rowsToDropIsNotPIC = df[~(df['PIC'].isin(['Manda', 'Ambun']))].index
rowsToDropIsNotPIC
# Out:
# Index([0, 13, 59, 60, 61, 135, 136, 138, 139, 140], dtype='int64')

# %%
# Delete based on the condition
df = df.drop(index=rowsToDropIsNotPIC)

# Adjust the index in ascending from start until finish
df = df.reset_index(drop=True)

# %%
df.info()
# Successfully adjust
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127 entries, 0 to 126
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   DATE         122 non-null    object
#  1   DEBIT        0 non-null      object
#  2   CREDIT       126 non-null    object
#  3   RECIPIENT    127 non-null    object
#  4   30           75 non-null     float64
#  5   20           32 non-null     float64
#  6   10           26 non-null     float64
#  7   L            34 non-null     float64
#  8   PIC          127 non-null    object
#  9   Unnamed: 9   1 non-null      float64
#  10  Unnamed: 10  0 non-null      float64
# dtypes: float64(6), object(5)
# memory usage: 11.0+ KB

# %%
df.head()
# The first rows that we don't use is successfully deleted
# Out:
#                   DATE DEBIT  CREDIT                RECIPIENT   30   20   10  \
# 0  2021-02-01 00:00:00   NaN  100000  Kak fira (pack of 30's)  1.0  NaN  NaN
# 1  2021-02-02 00:00:00   NaN   80000      Fira (pack of 20's)  NaN  1.0  NaN
# 2  2021-02-02 00:00:00   NaN   80000      Audi (pack of 20's)  NaN  1.0  NaN
# 3                  NaN   NaN   40000                    Santi  NaN  NaN  1.0
# 4  2021-02-04 00:00:00   NaN  180000                     Tari  1.0  1.0  NaN
#
#     L    PIC  Unnamed: 9  Unnamed: 10
# 0 NaN  Ambun         0.0          NaN
# 1 NaN  Ambun         NaN          NaN
# 2 NaN  Manda         NaN          NaN
# 3 NaN  Manda         NaN          NaN
# 4 NaN  Manda         NaN          NaN

# %%
df.tail()
# The last rows that we don't use is successfully deleted
# Out:
#                     DATE DEBIT  CREDIT   RECIPIENT   30   20   10    L    PIC  \
# 122  2021-02-03 00:00:00   NaN  275000     Aldhira  1.0  NaN  1.0  3.0  Manda
# 123  2021-02-28 00:00:00   NaN   90000    Mba lila  NaN  NaN  NaN  2.0  Manda
# 124  2021-02-28 00:00:00   NaN  125000       Ganis  NaN  1.0  NaN  1.0  Manda
# 125  2021-02-28 00:00:00   NaN   90000        Audi  NaN  NaN  NaN  2.0  Manda
# 126  2021-02-28 00:00:00   NaN  200000  Tante Rini  1.0  1.0  1.0  NaN  Manda
#
#      Unnamed: 9  Unnamed: 10
# 122         NaN          NaN
# 123         NaN          NaN
# 124         NaN          NaN
# 125         NaN          NaN
# 126         NaN          NaN

# %% [markdown]
# #### Rename `30`, `20`, `10`, `L` columns to make it easier to understand

# %%
df[[30, 20, 10, 'L']].head()
# Out:
#     30   20   10   L
# 0  1.0  NaN  NaN NaN
# 1  NaN  1.0  NaN NaN
# 2  NaN  1.0  NaN NaN
# 3  NaN  NaN  1.0 NaN
# 4  1.0  1.0  NaN NaN

# %%
# Rename the columns to improve readability
df = df.rename(columns={30:'Shumai 30 Pcs', 20:'Shumai 20 Pcs', 10:'Shumai 10 Pcs', 'L':'Chicken Lumpia 10 Pcs'})

# %%
df[['Shumai 30 Pcs', 'Shumai 20 Pcs', 'Shumai 10 Pcs', 'Chicken Lumpia 10 Pcs']]
# Now, it's getting better
# Out:
#      Shumai 30 Pcs  Shumai 20 Pcs  Shumai 10 Pcs  Chicken Lumpia 10 Pcs
# 0              1.0            NaN            NaN                    NaN
# 1              NaN            1.0            NaN                    NaN
# 2              NaN            1.0            NaN                    NaN
# 3              NaN            NaN            1.0                    NaN
# 4              1.0            1.0            NaN                    NaN
# ..             ...            ...            ...                    ...
# 122            1.0            NaN            1.0                    3.0
# 123            NaN            NaN            NaN                    2.0
# 124            NaN            1.0            NaN                    1.0
# 125            NaN            NaN            NaN                    2.0
# 126            1.0            1.0            1.0                    NaN
#
# [127 rows x 4 columns]

# %%
df.head()
# Out:
#                   DATE DEBIT  CREDIT                RECIPIENT  Shumai 30 Pcs  \
# 0  2021-02-01 00:00:00   NaN  100000  Kak fira (pack of 30's)            1.0
# 1  2021-02-02 00:00:00   NaN   80000      Fira (pack of 20's)            NaN
# 2  2021-02-02 00:00:00   NaN   80000      Audi (pack of 20's)            NaN
# 3                  NaN   NaN   40000                    Santi            NaN
# 4  2021-02-04 00:00:00   NaN  180000                     Tari            1.0
#
#    Shumai 20 Pcs  Shumai 10 Pcs  Chicken Lumpia 10 Pcs    PIC  Unnamed: 9  \
# 0            NaN            NaN                    NaN  Ambun         0.0
# 1            1.0            NaN                    NaN  Ambun         NaN
# 2            1.0            NaN                    NaN  Manda         NaN
# 3            NaN            1.0                    NaN  Manda         NaN
# 4            1.0            NaN                    NaN  Manda         NaN
#
#    Unnamed: 10
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %% [markdown]
# ### Missing Value

# %% [markdown]
# #### Impute missing values of `DATE` column with mode

# %%
df.info();
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127 entries, 0 to 126
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   DATE                   122 non-null    object
#  1   DEBIT                  0 non-null      object
#  2   CREDIT                 126 non-null    object
#  3   RECIPIENT              127 non-null    object
#  4   Shumai 30 Pcs          75 non-null     float64
#  5   Shumai 20 Pcs          32 non-null     float64
#  6   Shumai 10 Pcs          26 non-null     float64
#  7   Chicken Lumpia 10 Pcs  34 non-null     float64
#  8   PIC                    127 non-null    object
#  9   Unnamed: 9             1 non-null      float64
#  10  Unnamed: 10            0 non-null      float64
# dtypes: float64(6), object(5)
# memory usage: 11.0+ KB
#                   DATE DEBIT  CREDIT                RECIPIENT  Shumai 30 Pcs  \
# 0  2021-02-01 00:00:00   NaN  100000  Kak fira (pack of 30's)            1.0
# 1  2021-02-02 00:00:00   NaN   80000      Fira (pack of 20's)            NaN
# 2  2021-02-02 00:00:00   NaN   80000      Audi (pack of 20's)            NaN
# 3                  NaN   NaN   40000                    Santi            NaN
# 4  2021-02-04 00:00:00   NaN  180000                     Tari            1.0
#
#    Shumai 20 Pcs  Shumai 10 Pcs  Chicken Lumpia 10 Pcs    PIC  Unnamed: 9  \
# 0            NaN            NaN                    NaN  Ambun         0.0
# 1            1.0            NaN                    NaN  Ambun         NaN
# 2            1.0            NaN                    NaN  Manda         NaN
# 3            NaN            1.0                    NaN  Manda         NaN
# 4            1.0            NaN                    NaN  Manda         NaN
#
#    Unnamed: 10
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
df['DATE'].mode()
# Out:
# 0   2021-02-27
# Name: DATE, dtype: datetime64[ns]

# %%
# Impute missing values of `DATE` column with mode
df['DATE'] = df['DATE'].fillna(df['DATE'].mode()[0])

# %%
df.info();
df.head()
# Successfully fill with mode
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127 entries, 0 to 126
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   DATE                   127 non-null    datetime64[ns]
#  1   DEBIT                  0 non-null      object
#  2   CREDIT                 126 non-null    object
#  3   RECIPIENT              127 non-null    object
#  4   Shumai 30 Pcs          75 non-null     float64
#  5   Shumai 20 Pcs          32 non-null     float64
#  6   Shumai 10 Pcs          26 non-null     float64
#  7   Chicken Lumpia 10 Pcs  34 non-null     float64
#  8   PIC                    127 non-null    object
#  9   Unnamed: 9             1 non-null      float64
#  10  Unnamed: 10            0 non-null      float64
# dtypes: datetime64[ns](1), float64(6), object(4)
# memory usage: 11.0+ KB
#         DATE DEBIT  CREDIT                RECIPIENT  Shumai 30 Pcs  \
# 0 2021-02-01   NaN  100000  Kak fira (pack of 30's)            1.0
# 1 2021-02-02   NaN   80000      Fira (pack of 20's)            NaN
# 2 2021-02-02   NaN   80000      Audi (pack of 20's)            NaN
# 3 2021-02-27   NaN   40000                    Santi            NaN
# 4 2021-02-04   NaN  180000                     Tari            1.0
#
#    Shumai 20 Pcs  Shumai 10 Pcs  Chicken Lumpia 10 Pcs    PIC  Unnamed: 9  \
# 0            NaN            NaN                    NaN  Ambun         0.0
# 1            1.0            NaN                    NaN  Ambun         NaN
# 2            1.0            NaN                    NaN  Manda         NaN
# 3            NaN            1.0                    NaN  Manda         NaN
# 4            1.0            NaN                    NaN  Manda         NaN
#
#    Unnamed: 10
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %% [markdown]
# ### Inconsistent Data **#2**

# %% [markdown]
# #### Convert `DATE` column into the sum of the month selecting column that we want to use

# %%
# Turn 'DATE' into per month
df['DATE'] = df['DATE'].dt.to_period('M')

# Sum of the month and selecting column that we want to use
df = df.groupby('DATE')[['Shumai 30 Pcs', 'Shumai 20 Pcs', 'Shumai 10 Pcs', 'Chicken Lumpia 10 Pcs']].sum().reset_index()

# %%
df.head()
# Out:
#       DATE  Shumai 30 Pcs  Shumai 20 Pcs  Shumai 10 Pcs  Chicken Lumpia 10 Pcs
# 0  2021-02          101.0           35.0           30.0                   59.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   DATE                   1 non-null      period[M]
#  1   Shumai 30 Pcs          1 non-null      float64
#  2   Shumai 20 Pcs          1 non-null      float64
#  3   Shumai 10 Pcs          1 non-null      float64
#  4   Chicken Lumpia 10 Pcs  1 non-null      float64
# dtypes: float64(4), period[M](1)
# memory usage: 172.0 bytes

# %% [markdown]
# #### Convert the products category sales columns into integer

# %%
# Before convert the datatypes, we must ensure that the columns are not int
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   DATE                   1 non-null      period[M]
#  1   Shumai 30 Pcs          1 non-null      float64
#  2   Shumai 20 Pcs          1 non-null      float64
#  3   Shumai 10 Pcs          1 non-null      float64
#  4   Chicken Lumpia 10 Pcs  1 non-null      float64
# dtypes: float64(4), period[M](1)
# memory usage: 172.0 bytes

# %%
# Convert into int64
df = df.astype({'Shumai 30 Pcs':'int64', 'Shumai 20 Pcs':'int64', 
                'Shumai 10 Pcs':'int64', 'Chicken Lumpia 10 Pcs':'int64'})

# %%
df.info();
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   DATE                   1 non-null      period[M]
#  1   Shumai 30 Pcs          1 non-null      int64
#  2   Shumai 20 Pcs          1 non-null      int64
#  3   Shumai 10 Pcs          1 non-null      int64
#  4   Chicken Lumpia 10 Pcs  1 non-null      int64
# dtypes: int64(4), period[M](1)
# memory usage: 172.0 bytes
#       DATE  Shumai 30 Pcs  Shumai 20 Pcs  Shumai 10 Pcs  Chicken Lumpia 10 Pcs
# 0  2021-02            101             35             30                     59

# %% [markdown]
# ## Export the dataframe into excel files

# %%
# Load datasets and convert it into excel based on month of sales's sheets
df = df.to_excel(r"..\..\data\dataCleaning\FEB21_dataCleaning.xlsx", index=False)

# %%
# selecting columns where column name contains 'Average' string
# df.filter(like='Average')
