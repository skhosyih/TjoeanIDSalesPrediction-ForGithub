# %% [markdown]
# # MAR21 - Data Cleaning

# %% [markdown]
# ## Data Gather

# %% [markdown]
# ### Importing libraries and load the datasets

# %%
from datetime import datetime
import pandas as pd
from openpyxl import Workbook
import numpy as np

# %%
#  Load the datasets
df = pd.read_excel(r"..\..\data\gatherData\MAR21_DimsumTJOEAN.xlsx")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98 entries, 0 to 97
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   DATE        83 non-null     datetime64[ns]
#  1   DEBIT       7 non-null      object
#  2   CREDIT      89 non-null     object
#  3   RECIPIENT   87 non-null     object
#  4   30          48 non-null     float64
#  5   20          20 non-null     float64
#  6   10          20 non-null     float64
#  7   L           62 non-null     float64
#  8   PIC         84 non-null     object
#  9   Unnamed: 9  13 non-null     object
# dtypes: datetime64[ns](1), float64(4), object(5)
# memory usage: 7.8+ KB

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Inconsistent Data **#1**

# %% [markdown]
# #### Delete `NaN` rows and the inconsistent rows that we don't use

# %% [markdown]
# ##### Delete `NaN` rows

# %%
df.tail()
# Out:
#    DATE    DEBIT     CREDIT               RECIPIENT      30      20     10  \
# 93  NaT    manda  40 dimsum  TOTAL PENJUALAN TJOEAN   254.0    83.0   93.0
# 94  NaT      NaN  50 hekeng                   11790  7620.0  1660.0  930.0
# 95  NaT    ambun  20 dimsum                     NaN     NaN     NaN    NaN
# 96  NaT      NaN  20 hekeng                     NaN     NaN     NaN    NaN
# 97  NaT  PIUTANG        NaN                     600   450.0    80.0   70.0
#
#          L  PIC Unnamed: 9
# 93   158.0  NaN        NaN
# 94  1580.0  NaN        NaN
# 95     NaN  NaN        NaN
# 96     NaN  NaN        NaN
# 97     NaN  NaN        NaN

# %%
# Rows to drop
rowsToDrop = df[df.isnull().all(axis=1)].index
rowsToDrop
# In a beginning of rows, there are also a 'NaN' values
# Out:
# Index([84, 87, 88, 91], dtype='int64')

# %%
# Delete based on the condition
df = df.drop(index=rowsToDrop)

# %%
df.tail()
# There isn't the all columns have 'NaN' values
# Out:
#    DATE    DEBIT     CREDIT               RECIPIENT      30      20     10  \
# 93  NaT    manda  40 dimsum  TOTAL PENJUALAN TJOEAN   254.0    83.0   93.0
# 94  NaT      NaN  50 hekeng                   11790  7620.0  1660.0  930.0
# 95  NaT    ambun  20 dimsum                     NaN     NaN     NaN    NaN
# 96  NaT      NaN  20 hekeng                     NaN     NaN     NaN    NaN
# 97  NaT  PIUTANG        NaN                     600   450.0    80.0   70.0
#
#          L  PIC Unnamed: 9
# 93   158.0  NaN        NaN
# 94  1580.0  NaN        NaN
# 95     NaN  NaN        NaN
# 96     NaN  NaN        NaN
# 97     NaN  NaN        NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 94 entries, 0 to 97
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   DATE        83 non-null     datetime64[ns]
#  1   DEBIT       7 non-null      object
#  2   CREDIT      89 non-null     object
#  3   RECIPIENT   87 non-null     object
#  4   30          48 non-null     float64
#  5   20          20 non-null     float64
#  6   10          20 non-null     float64
#  7   L           62 non-null     float64
#  8   PIC         84 non-null     object
#  9   Unnamed: 9  13 non-null     object
# dtypes: datetime64[ns](1), float64(4), object(5)
# memory usage: 8.1+ KB

# %% [markdown]
# ##### Delete the inconsistent rows that we don't use

# %%
df.head()
# Out:
#         DATE DEBIT    CREDIT   RECIPIENT     30    20    10     L    PIC  \
# 0        NaT   NaN  29525000  February's  104.0  35.0  31.0  59.0    NaN
# 1 2021-03-01   NaN     85000       Intan    NaN   NaN   1.0   1.0  Manda
# 2 2021-03-02   NaN    135000      Celvin    NaN   NaN   NaN   3.0  Manda
# 3 2021-03-01   NaN    380000        Reni    2.0   NaN   NaN   4.0  Manda
# 4 2021-03-05   NaN    135000      Nabila    NaN   NaN   NaN   3.0  Manda
#
#   Unnamed: 9
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %%
df.tail(6)
# Out:
#    DATE    DEBIT     CREDIT               RECIPIENT      30      20     10  \
# 92  NaT    UTANG        NaN                     NaN     NaN     NaN    NaN
# 93  NaT    manda  40 dimsum  TOTAL PENJUALAN TJOEAN   254.0    83.0   93.0
# 94  NaT      NaN  50 hekeng                   11790  7620.0  1660.0  930.0
# 95  NaT    ambun  20 dimsum                     NaN     NaN     NaN    NaN
# 96  NaT      NaN  20 hekeng                     NaN     NaN     NaN    NaN
# 97  NaT  PIUTANG        NaN                     600   450.0    80.0   70.0
#
#          L  PIC Unnamed: 9
# 92     NaN  NaN        NaN
# 93   158.0  NaN        NaN
# 94  1580.0  NaN        NaN
# 95     NaN  NaN        NaN
# 96     NaN  NaN        NaN
# 97     NaN  NaN        NaN

# %%
# Condition where 'PIC' column values is not Manda and Ambun
rowsToDropIsNotPIC = df[~(df['PIC'].isin(['Manda', 'Ambun']))].index
rowsToDropIsNotPIC
# Out:
# Index([0, 30, 47, 70, 73, 77, 85, 86, 89, 90, 92, 93, 94, 95, 96, 97], dtype='int64')

# %%
# Delete based on the condition
df = df.drop(index=rowsToDropIsNotPIC)

# Adjust the index in ascending from start until finish
df = df.reset_index(drop=True)

# %%
df.info()
# Successfully adjust
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   DATE        78 non-null     datetime64[ns]
#  1   DEBIT       0 non-null      object
#  2   CREDIT      78 non-null     object
#  3   RECIPIENT   78 non-null     object
#  4   30          42 non-null     float64
#  5   20          14 non-null     float64
#  6   10          13 non-null     float64
#  7   L           54 non-null     float64
#  8   PIC         78 non-null     object
#  9   Unnamed: 9  13 non-null     object
# dtypes: datetime64[ns](1), float64(4), object(5)
# memory usage: 6.2+ KB

# %%
df.head()
# The first rows that we don't use is successfully deleted
# Out:
#         DATE DEBIT  CREDIT RECIPIENT   30  20   10    L    PIC Unnamed: 9
# 0 2021-03-01   NaN   85000     Intan  NaN NaN  1.0  1.0  Manda        NaN
# 1 2021-03-02   NaN  135000    Celvin  NaN NaN  NaN  3.0  Manda        NaN
# 2 2021-03-01   NaN  380000      Reni  2.0 NaN  NaN  4.0  Manda        NaN
# 3 2021-03-05   NaN  135000    Nabila  NaN NaN  NaN  3.0  Manda        NaN
# 4 2021-03-01   NaN  100000      Gery  1.0 NaN  NaN  NaN  Manda        NaN

# %%
df.tail()
# The last rows that we don't use is successfully deleted
# Out:
#          DATE DEBIT  CREDIT             RECIPIENT   30  20   10    L    PIC  \
# 73 2021-03-28   NaN  145000          Kak tya (IG)  1.0 NaN  NaN  1.0  Manda
# 74 2021-03-28   NaN  100000              Mba didi  1.0 NaN  NaN  NaN  Manda
# 75 2021-03-28   NaN  100000  Uti for Tante frisbi  1.0 NaN  NaN  NaN  Ambun
# 76 2021-03-29   NaN  345000                 Ichay  2.0 NaN  3.0  1.0  Ambun
# 77 2021-03-31   NaN  200000       Ibu Melina (IG)  2.0 NaN  NaN  NaN  Manda
#
#     Unnamed: 9
# 73         NaN
# 74         NaN
# 75         NaN
# 76         NaN
# 77  NO SEAFOOD

# %% [markdown]
# #### Rename `30`, `20`, `10`, `L` columns to make it easier to understand

# %%
df[[30, 20, 10, 'L']].head()
# Out:
#     30  20   10    L
# 0  NaN NaN  1.0  1.0
# 1  NaN NaN  NaN  3.0
# 2  2.0 NaN  NaN  4.0
# 3  NaN NaN  NaN  3.0
# 4  1.0 NaN  NaN  NaN

# %%
# Rename the columns to improve readability
df = df.rename(columns={30:'Shumai 30 Pcs', 20:'Shumai 20 Pcs', 10:'Shumai 10 Pcs', 'L':'Chicken Lumpia 10 Pcs'})

# %%
df[['Shumai 30 Pcs', 'Shumai 20 Pcs', 'Shumai 10 Pcs', 'Chicken Lumpia 10 Pcs']]
# Now, it's getting better
# Out:
#     Shumai 30 Pcs  Shumai 20 Pcs  Shumai 10 Pcs  Chicken Lumpia 10 Pcs
# 0             NaN            NaN            1.0                    1.0
# 1             NaN            NaN            NaN                    3.0
# 2             2.0            NaN            NaN                    4.0
# 3             NaN            NaN            NaN                    3.0
# 4             1.0            NaN            NaN                    NaN
# ..            ...            ...            ...                    ...
# 73            1.0            NaN            NaN                    1.0
# 74            1.0            NaN            NaN                    NaN
# 75            1.0            NaN            NaN                    NaN
# 76            2.0            NaN            3.0                    1.0
# 77            2.0            NaN            NaN                    NaN
#
# [78 rows x 4 columns]

# %%
df.head()
# Out:
#         DATE DEBIT  CREDIT RECIPIENT  Shumai 30 Pcs  Shumai 20 Pcs  \
# 0 2021-03-01   NaN   85000     Intan            NaN            NaN
# 1 2021-03-02   NaN  135000    Celvin            NaN            NaN
# 2 2021-03-01   NaN  380000      Reni            2.0            NaN
# 3 2021-03-05   NaN  135000    Nabila            NaN            NaN
# 4 2021-03-01   NaN  100000      Gery            1.0            NaN
#
#    Shumai 10 Pcs  Chicken Lumpia 10 Pcs    PIC Unnamed: 9
# 0            1.0                    1.0  Manda        NaN
# 1            NaN                    3.0  Manda        NaN
# 2            NaN                    4.0  Manda        NaN
# 3            NaN                    3.0  Manda        NaN
# 4            NaN                    NaN  Manda        NaN

# %% [markdown]
# ### Missing Value

# %% [markdown]
# #### Impute missing values of `DATE` column with mode

# %%
df.info();
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   DATE                   78 non-null     datetime64[ns]
#  1   DEBIT                  0 non-null      object
#  2   CREDIT                 78 non-null     object
#  3   RECIPIENT              78 non-null     object
#  4   Shumai 30 Pcs          42 non-null     float64
#  5   Shumai 20 Pcs          14 non-null     float64
#  6   Shumai 10 Pcs          13 non-null     float64
#  7   Chicken Lumpia 10 Pcs  54 non-null     float64
#  8   PIC                    78 non-null     object
#  9   Unnamed: 9             13 non-null     object
# dtypes: datetime64[ns](1), float64(4), object(5)
# memory usage: 6.2+ KB
#         DATE DEBIT  CREDIT RECIPIENT  Shumai 30 Pcs  Shumai 20 Pcs  \
# 0 2021-03-01   NaN   85000     Intan            NaN            NaN
# 1 2021-03-02   NaN  135000    Celvin            NaN            NaN
# 2 2021-03-01   NaN  380000      Reni            2.0            NaN
# 3 2021-03-05   NaN  135000    Nabila            NaN            NaN
# 4 2021-03-01   NaN  100000      Gery            1.0            NaN
#
#    Shumai 10 Pcs  Chicken Lumpia 10 Pcs    PIC Unnamed: 9
# 0            1.0                    1.0  Manda        NaN
# 1            NaN                    3.0  Manda        NaN
# 2            NaN                    4.0  Manda        NaN
# 3            NaN                    3.0  Manda        NaN
# 4            NaN                    NaN  Manda        NaN

# %%
df['DATE'].mode()
# Out:
# 0   2021-03-04
# Name: DATE, dtype: datetime64[ns]

# %%
# Impute missing values of `DATE` column with mode
df['DATE'] = df['DATE'].fillna(df['DATE'].mode()[0])

# %%
df.info();
df.head()
# Successfully fill with mode
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   DATE                   78 non-null     datetime64[ns]
#  1   DEBIT                  0 non-null      object
#  2   CREDIT                 78 non-null     object
#  3   RECIPIENT              78 non-null     object
#  4   Shumai 30 Pcs          42 non-null     float64
#  5   Shumai 20 Pcs          14 non-null     float64
#  6   Shumai 10 Pcs          13 non-null     float64
#  7   Chicken Lumpia 10 Pcs  54 non-null     float64
#  8   PIC                    78 non-null     object
#  9   Unnamed: 9             13 non-null     object
# dtypes: datetime64[ns](1), float64(4), object(5)
# memory usage: 6.2+ KB
#         DATE DEBIT  CREDIT RECIPIENT  Shumai 30 Pcs  Shumai 20 Pcs  \
# 0 2021-03-01   NaN   85000     Intan            NaN            NaN
# 1 2021-03-02   NaN  135000    Celvin            NaN            NaN
# 2 2021-03-01   NaN  380000      Reni            2.0            NaN
# 3 2021-03-05   NaN  135000    Nabila            NaN            NaN
# 4 2021-03-01   NaN  100000      Gery            1.0            NaN
#
#    Shumai 10 Pcs  Chicken Lumpia 10 Pcs    PIC Unnamed: 9
# 0            1.0                    1.0  Manda        NaN
# 1            NaN                    3.0  Manda        NaN
# 2            NaN                    4.0  Manda        NaN
# 3            NaN                    3.0  Manda        NaN
# 4            NaN                    NaN  Manda        NaN

# %% [markdown]
# #### Impute missing values of `Shumai 10 Pcs`, `Shumai 20 Pcs`, `Shumai 30 Pcs`, `Chicken Lumpia 10 Pcs` column with 0

# %%
df.info();
df.head()
# As you can see, there's null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   DATE                   78 non-null     datetime64[ns]
#  1   DEBIT                  0 non-null      object
#  2   CREDIT                 78 non-null     object
#  3   RECIPIENT              78 non-null     object
#  4   Shumai 30 Pcs          42 non-null     float64
#  5   Shumai 20 Pcs          14 non-null     float64
#  6   Shumai 10 Pcs          13 non-null     float64
#  7   Chicken Lumpia 10 Pcs  54 non-null     float64
#  8   PIC                    78 non-null     object
#  9   Unnamed: 9             13 non-null     object
# dtypes: datetime64[ns](1), float64(4), object(5)
# memory usage: 6.2+ KB
#         DATE DEBIT  CREDIT RECIPIENT  Shumai 30 Pcs  Shumai 20 Pcs  \
# 0 2021-03-01   NaN   85000     Intan            NaN            NaN
# 1 2021-03-02   NaN  135000    Celvin            NaN            NaN
# 2 2021-03-01   NaN  380000      Reni            2.0            NaN
# 3 2021-03-05   NaN  135000    Nabila            NaN            NaN
# 4 2021-03-01   NaN  100000      Gery            1.0            NaN
#
#    Shumai 10 Pcs  Chicken Lumpia 10 Pcs    PIC Unnamed: 9
# 0            1.0                    1.0  Manda        NaN
# 1            NaN                    3.0  Manda        NaN
# 2            NaN                    4.0  Manda        NaN
# 3            NaN                    3.0  Manda        NaN
# 4            NaN                    NaN  Manda        NaN

# %%
# List of columns
listOfProducts = ['Shumai 10 Pcs', 'Shumai 20 Pcs', 'Shumai 30 Pcs', 'Chicken Lumpia 10 Pcs']

# Impute missing values of products column with 0 
for cols in listOfProducts:
    for i in range(1, len(df)+1):
        df[cols] = df[cols].fillna(0)

df.info();
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   DATE                   78 non-null     datetime64[ns]
#  1   DEBIT                  0 non-null      object
#  2   CREDIT                 78 non-null     object
#  3   RECIPIENT              78 non-null     object
#  4   Shumai 30 Pcs          78 non-null     float64
#  5   Shumai 20 Pcs          78 non-null     float64
#  6   Shumai 10 Pcs          78 non-null     float64
#  7   Chicken Lumpia 10 Pcs  78 non-null     float64
#  8   PIC                    78 non-null     object
#  9   Unnamed: 9             13 non-null     object
# dtypes: datetime64[ns](1), float64(4), object(5)
# memory usage: 6.2+ KB
#         DATE DEBIT  CREDIT RECIPIENT  Shumai 30 Pcs  Shumai 20 Pcs  \
# 0 2021-03-01   NaN   85000     Intan            0.0            0.0
# 1 2021-03-02   NaN  135000    Celvin            0.0            0.0
# 2 2021-03-01   NaN  380000      Reni            2.0            0.0
# 3 2021-03-05   NaN  135000    Nabila            0.0            0.0
# 4 2021-03-01   NaN  100000      Gery            1.0            0.0
#
#    Shumai 10 Pcs  Chicken Lumpia 10 Pcs    PIC Unnamed: 9
# 0            1.0                    1.0  Manda        NaN
# 1            0.0                    3.0  Manda        NaN
# 2            0.0                    4.0  Manda        NaN
# 3            0.0                    3.0  Manda        NaN
# 4            0.0                    0.0  Manda        NaN

# %% [markdown]
# ### Inconsistent Data **#2**

# %% [markdown]
# #### Convert the products category sales columns into integer

# %%
# Before convert the datatypes, we must ensure that the columns are not int
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   DATE                   78 non-null     datetime64[ns]
#  1   DEBIT                  0 non-null      object
#  2   CREDIT                 78 non-null     object
#  3   RECIPIENT              78 non-null     object
#  4   Shumai 30 Pcs          78 non-null     float64
#  5   Shumai 20 Pcs          78 non-null     float64
#  6   Shumai 10 Pcs          78 non-null     float64
#  7   Chicken Lumpia 10 Pcs  78 non-null     float64
#  8   PIC                    78 non-null     object
#  9   Unnamed: 9             13 non-null     object
# dtypes: datetime64[ns](1), float64(4), object(5)
# memory usage: 6.2+ KB

# %%
# List of columns
listOfProducts = ['Shumai 10 Pcs', 'Shumai 20 Pcs', 'Shumai 30 Pcs', 'Chicken Lumpia 10 Pcs']

# Convert into int64
for cols in listOfProducts:
    for i in range(1, len(df)+1):
        df[cols] = df[cols].astype('int64')

df.info();
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   DATE                   78 non-null     datetime64[ns]
#  1   DEBIT                  0 non-null      object
#  2   CREDIT                 78 non-null     object
#  3   RECIPIENT              78 non-null     object
#  4   Shumai 30 Pcs          78 non-null     int64
#  5   Shumai 20 Pcs          78 non-null     int64
#  6   Shumai 10 Pcs          78 non-null     int64
#  7   Chicken Lumpia 10 Pcs  78 non-null     int64
#  8   PIC                    78 non-null     object
#  9   Unnamed: 9             13 non-null     object
# dtypes: datetime64[ns](1), int64(4), object(5)
# memory usage: 6.2+ KB
#         DATE DEBIT  CREDIT RECIPIENT  Shumai 30 Pcs  Shumai 20 Pcs  \
# 0 2021-03-01   NaN   85000     Intan              0              0
# 1 2021-03-02   NaN  135000    Celvin              0              0
# 2 2021-03-01   NaN  380000      Reni              2              0
# 3 2021-03-05   NaN  135000    Nabila              0              0
# 4 2021-03-01   NaN  100000      Gery              1              0
#
#    Shumai 10 Pcs  Chicken Lumpia 10 Pcs    PIC Unnamed: 9
# 0              1                      1  Manda        NaN
# 1              0                      3  Manda        NaN
# 2              0                      4  Manda        NaN
# 3              0                      3  Manda        NaN
# 4              0                      0  Manda        NaN

# %% [markdown]
# ## Data Selection

# %% [markdown]
# ### Select certain data

# %%
df.info();
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   DATE                   78 non-null     datetime64[ns]
#  1   DEBIT                  0 non-null      object
#  2   CREDIT                 78 non-null     object
#  3   RECIPIENT              78 non-null     object
#  4   Shumai 30 Pcs          78 non-null     int64
#  5   Shumai 20 Pcs          78 non-null     int64
#  6   Shumai 10 Pcs          78 non-null     int64
#  7   Chicken Lumpia 10 Pcs  78 non-null     int64
#  8   PIC                    78 non-null     object
#  9   Unnamed: 9             13 non-null     object
# dtypes: datetime64[ns](1), int64(4), object(5)
# memory usage: 6.2+ KB
#         DATE DEBIT  CREDIT RECIPIENT  Shumai 30 Pcs  Shumai 20 Pcs  \
# 0 2021-03-01   NaN   85000     Intan              0              0
# 1 2021-03-02   NaN  135000    Celvin              0              0
# 2 2021-03-01   NaN  380000      Reni              2              0
# 3 2021-03-05   NaN  135000    Nabila              0              0
# 4 2021-03-01   NaN  100000      Gery              1              0
#
#    Shumai 10 Pcs  Chicken Lumpia 10 Pcs    PIC Unnamed: 9
# 0              1                      1  Manda        NaN
# 1              0                      3  Manda        NaN
# 2              0                      4  Manda        NaN
# 3              0                      3  Manda        NaN
# 4              0                      0  Manda        NaN

# %%
# Delete `DEBIT`, `CREDIT`, `RECIPIENT`, and `PIC` since we don't use it
df = df.drop(columns=['DEBIT', 'CREDIT', 'RECIPIENT', 'PIC', ])

# Delete columns that starts with 'Unnamed'
df = df.loc[:, ~df.columns.str.startswith('Unnamed')]

df.info();
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   DATE                   78 non-null     datetime64[ns]
#  1   Shumai 30 Pcs          78 non-null     int64
#  2   Shumai 20 Pcs          78 non-null     int64
#  3   Shumai 10 Pcs          78 non-null     int64
#  4   Chicken Lumpia 10 Pcs  78 non-null     int64
# dtypes: datetime64[ns](1), int64(4)
# memory usage: 3.2 KB
#         DATE  Shumai 30 Pcs  Shumai 20 Pcs  Shumai 10 Pcs  \
# 0 2021-03-01              0              0              1
# 1 2021-03-02              0              0              0
# 2 2021-03-01              2              0              0
# 3 2021-03-05              0              0              0
# 4 2021-03-01              1              0              0
#
#    Chicken Lumpia 10 Pcs
# 0                      1
# 1                      3
# 2                      4
# 3                      3
# 4                      0

# %% [markdown]
# ## Export the dataframe into excel files

# %%
# Load datasets and convert it into excel based on month of sales's sheets
df = df.to_excel(r"..\..\data\dataCleaningOne\MAR21_dataCleaning.xlsx", index=False)

# %%
# selecting columns where column name contains 'Average' string
# df.filter(like='Average')
