# %% [markdown]
# # JAN21 - Data Cleaning

# %% [markdown]
# ## Data Gather

# %% [markdown]
# ### Importing libraries and load the datasets

# %%
from datetime import datetime
import pandas as pd
from openpyxl import Workbook
import numpy as np

# %%
#  Load the datasets
df = pd.read_excel(r"..\..\data\gatherData\JAN21_DimsumTJOEAN.xlsx")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121 entries, 0 to 120
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   DATE       73 non-null     datetime64[ns]
#  1   DEBIT      2 non-null      object
#  2   CREDIT     115 non-null    object
#  3   RECIPIENT  112 non-null    object
#  4   30         63 non-null     float64
#  5   20         29 non-null     float64
#  6   10         26 non-null     float64
#  7   PIC        105 non-null    object
# dtypes: datetime64[ns](1), float64(3), object(4)
# memory usage: 7.7+ KB

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Inconsistent Data **#1**

# %% [markdown]
# #### Delete `NaN` rows from first occurrence

# %%
df.tail(20)
# Out:
#           DATE             DEBIT  \
# 101 2021-01-31               NaN
# 102 2021-01-31               NaN
# 103 2021-01-31               NaN
# 104        NaT               NaN
# 105        NaT               NaN
# 106        NaT           #TJOEAN
# 107        NaT               NaN
# 108        NaT               NaN
# 109        NaT               NaN
# 110        NaT  Promotion Budget
# 111        NaT               NaN
# 112        NaT               NaN
# 113        NaT               NaN
# 114        NaT               NaN
# 115        NaT               NaN
# 116        NaT               NaN
# 117        NaT               NaN
# 118        NaT               NaN
# 119        NaT               NaN
# 120        NaT               NaN
#
#                                              CREDIT            RECIPIENT  \
# 101                                          100000          Mba diandra
# 102                                          300000          Melina (IG)
# 103                                          100000  Nacil (temen ilham)
# 104                                             NaN                  NaN
# 105                                        13010000                  NaN
# 106                                             NaN                  NaN
# 107                                             NaN                  NaN
# 108                                             NaN                  NaN
# 109                                             NaN                  NaN
# 110                                              10                  Ayu
# 111                                              10                 Cici
# 112                                              10           Tante Gati
# 113                                              10                 Riri
# 114                                              10                Intan
# 115                                              10                  Avi
# 116                                              30                Dhana
# 117                                              30           Uda Faizal
# 118                                             120                  NaN
# 119                                             NaN                  NaN
# 120  tante naz+buica udah di tambahin di debit un ?                  NaN
#
#        30    20    10    PIC
# 101   1.0   NaN   NaN  Manda
# 102   2.0   1.0   1.0  Manda
# 103   1.0   NaN   NaN  Ambun
# 104   NaN   NaN   NaN    NaN
# 105  92.0  32.0  35.0  TOTAL
# 106   NaN   NaN   NaN    NaN
# 107   NaN   NaN   NaN    NaN
# 108   NaN   NaN   NaN    NaN
# 109   NaN   NaN   NaN    NaN
# 110   NaN   NaN   NaN    NaN
# 111   NaN   NaN   NaN    NaN
# 112   NaN   NaN   NaN    NaN
# 113   NaN   NaN   NaN    NaN
# 114   NaN   NaN   NaN    NaN
# 115   NaN   NaN   NaN    NaN
# 116   NaN   NaN   NaN    NaN
# 117   NaN   NaN   NaN    NaN
# 118   NaN   NaN   NaN    NaN
# 119   NaN   NaN   NaN    NaN
# 120   NaN   NaN   NaN    NaN

# %%
# Rows to drop
rowsToDrop = df[df.isnull().all(axis=1)].index

# Drop the first occurence of 'NaN' values etc
df = df.drop(index=range(rowsToDrop[0], rowsToDrop[-1] + 1))

# %%
df.tail(3)
# There isn't the all columns have 'NaN' values
# Out:
#           DATE DEBIT                                          CREDIT  \
# 102 2021-01-31   NaN                                          300000
# 103 2021-01-31   NaN                                          100000
# 120        NaT   NaN  tante naz+buica udah di tambahin di debit un ?
#
#                RECIPIENT   30   20   10    PIC
# 102          Melina (IG)  2.0  1.0  1.0  Manda
# 103  Nacil (temen ilham)  1.0  NaN  NaN  Ambun
# 120                  NaN  NaN  NaN  NaN    NaN

# %%
# Adjust the index in ascending from start until finish
df = df.reset_index(drop=True)

# %%
df.tail(3)
# Successfully adjust
# Out:
#           DATE DEBIT                                          CREDIT  \
# 102 2021-01-31   NaN                                          300000
# 103 2021-01-31   NaN                                          100000
# 104        NaT   NaN  tante naz+buica udah di tambahin di debit un ?
#
#                RECIPIENT   30   20   10    PIC
# 102          Melina (IG)  2.0  1.0  1.0  Manda
# 103  Nacil (temen ilham)  1.0  NaN  NaN  Ambun
# 104                  NaN  NaN  NaN  NaN    NaN

# %% [markdown]
# #### Delete the last rows that we don't use

# %%
df = df.drop(df.index[-1])

# %%
df.tail(3)
# The last rows that we don't use is successfully deleted
# Out:
#           DATE DEBIT  CREDIT            RECIPIENT   30   20   10    PIC
# 101 2021-01-31   NaN  100000          Mba diandra  1.0  NaN  NaN  Manda
# 102 2021-01-31   NaN  300000          Melina (IG)  2.0  1.0  1.0  Manda
# 103 2021-01-31   NaN  100000  Nacil (temen ilham)  1.0  NaN  NaN  Ambun

# %% [markdown]
# #### Rename `30`, `20`, `10` columns to make it easier to understand

# %%
df[[30, 20, 10]].head()
# Out:
#     30   20  10
# 0  1.0  NaN NaN
# 1  2.0  NaN NaN
# 2  1.0  NaN NaN
# 3  1.0  NaN NaN
# 4  NaN  1.0 NaN

# %%
# Rename the columns to improve readability
df = df.rename(columns={30:'Shumai 30 Pcs', 20:'Shumai 20 Pcs', 10:'Shumai 10 Pcs'})

# %%
df[['Shumai 30 Pcs', 'Shumai 20 Pcs', 'Shumai 10 Pcs']]
# Now, it's getting better
# Out:
#      Shumai 30 Pcs  Shumai 20 Pcs  Shumai 10 Pcs
# 0              1.0            NaN            NaN
# 1              2.0            NaN            NaN
# 2              1.0            NaN            NaN
# 3              1.0            NaN            NaN
# 4              NaN            1.0            NaN
# ..             ...            ...            ...
# 99             2.0            NaN            NaN
# 100            1.0            NaN            NaN
# 101            1.0            NaN            NaN
# 102            2.0            1.0            1.0
# 103            1.0            NaN            NaN
#
# [104 rows x 3 columns]

# %%
df.head()
# Out:
#         DATE DEBIT  CREDIT               RECIPIENT  Shumai 30 Pcs  \
# 0        NaT   NaN  100000    Intan (pack of 30's)            1.0
# 1        NaT   NaN  200000  Steffie (pack of 60's)            2.0
# 2        NaT   NaN  100000     Ajis (pack of 30's)            1.0
# 3        NaT   NaN  100000     Riri (pack of 30's)            1.0
# 4 2021-01-14   NaN   80000    Afuza (pack of 20's)            NaN
#
#    Shumai 20 Pcs  Shumai 10 Pcs    PIC
# 0            NaN            NaN  Manda
# 1            NaN            NaN  Manda
# 2            NaN            NaN  Manda
# 3            NaN            NaN  Manda
# 4            1.0            NaN  Ambun

# %% [markdown]
# ### Missing Value

# %% [markdown]
# #### Impute missing values of `DATE` column with mode

# %%
df.info();
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104 entries, 0 to 103
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   DATE           73 non-null     datetime64[ns]
#  1   DEBIT          0 non-null      object
#  2   CREDIT         104 non-null    object
#  3   RECIPIENT      104 non-null    object
#  4   Shumai 30 Pcs  62 non-null     float64
#  5   Shumai 20 Pcs  28 non-null     float64
#  6   Shumai 10 Pcs  25 non-null     float64
#  7   PIC            104 non-null    object
# dtypes: datetime64[ns](1), float64(3), object(4)
# memory usage: 6.6+ KB
#         DATE DEBIT  CREDIT               RECIPIENT  Shumai 30 Pcs  \
# 0        NaT   NaN  100000    Intan (pack of 30's)            1.0
# 1        NaT   NaN  200000  Steffie (pack of 60's)            2.0
# 2        NaT   NaN  100000     Ajis (pack of 30's)            1.0
# 3        NaT   NaN  100000     Riri (pack of 30's)            1.0
# 4 2021-01-14   NaN   80000    Afuza (pack of 20's)            NaN
#
#    Shumai 20 Pcs  Shumai 10 Pcs    PIC
# 0            NaN            NaN  Manda
# 1            NaN            NaN  Manda
# 2            NaN            NaN  Manda
# 3            NaN            NaN  Manda
# 4            1.0            NaN  Ambun

# %%
df['DATE'].mode()
# Out:
# 0   2021-01-29
# 1   2021-01-31
# Name: DATE, dtype: datetime64[ns]

# %%
# Impute missing values of `DATE` column with mode
df['DATE'] = df['DATE'].fillna(df['DATE'].mode()[0])

# %%
df.info();
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104 entries, 0 to 103
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   DATE           104 non-null    datetime64[ns]
#  1   DEBIT          0 non-null      object
#  2   CREDIT         104 non-null    object
#  3   RECIPIENT      104 non-null    object
#  4   Shumai 30 Pcs  62 non-null     float64
#  5   Shumai 20 Pcs  28 non-null     float64
#  6   Shumai 10 Pcs  25 non-null     float64
#  7   PIC            104 non-null    object
# dtypes: datetime64[ns](1), float64(3), object(4)
# memory usage: 6.6+ KB
#         DATE DEBIT  CREDIT               RECIPIENT  Shumai 30 Pcs  \
# 0 2021-01-29   NaN  100000    Intan (pack of 30's)            1.0
# 1 2021-01-29   NaN  200000  Steffie (pack of 60's)            2.0
# 2 2021-01-29   NaN  100000     Ajis (pack of 30's)            1.0
# 3 2021-01-29   NaN  100000     Riri (pack of 30's)            1.0
# 4 2021-01-14   NaN   80000    Afuza (pack of 20's)            NaN
#
#    Shumai 20 Pcs  Shumai 10 Pcs    PIC
# 0            NaN            NaN  Manda
# 1            NaN            NaN  Manda
# 2            NaN            NaN  Manda
# 3            NaN            NaN  Manda
# 4            1.0            NaN  Ambun

# %% [markdown]
# #### Impute missing values of `Shumai 10 Pcs`, `Shumai 20 Pcs`, `Shumai 30 Pcs`, column with 0

# %%
df.info();
df.head()
# As you can see, there's null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104 entries, 0 to 103
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   DATE           104 non-null    datetime64[ns]
#  1   DEBIT          0 non-null      object
#  2   CREDIT         104 non-null    object
#  3   RECIPIENT      104 non-null    object
#  4   Shumai 30 Pcs  62 non-null     float64
#  5   Shumai 20 Pcs  28 non-null     float64
#  6   Shumai 10 Pcs  25 non-null     float64
#  7   PIC            104 non-null    object
# dtypes: datetime64[ns](1), float64(3), object(4)
# memory usage: 6.6+ KB
#         DATE DEBIT  CREDIT               RECIPIENT  Shumai 30 Pcs  \
# 0 2021-01-29   NaN  100000    Intan (pack of 30's)            1.0
# 1 2021-01-29   NaN  200000  Steffie (pack of 60's)            2.0
# 2 2021-01-29   NaN  100000     Ajis (pack of 30's)            1.0
# 3 2021-01-29   NaN  100000     Riri (pack of 30's)            1.0
# 4 2021-01-14   NaN   80000    Afuza (pack of 20's)            NaN
#
#    Shumai 20 Pcs  Shumai 10 Pcs    PIC
# 0            NaN            NaN  Manda
# 1            NaN            NaN  Manda
# 2            NaN            NaN  Manda
# 3            NaN            NaN  Manda
# 4            1.0            NaN  Ambun

# %%
# List of columns
listOfProducts = ['Shumai 10 Pcs', 'Shumai 20 Pcs', 'Shumai 30 Pcs']

# Impute missing values of products column with 0 
for cols in listOfProducts:
    for i in range(1, len(df)+1):
        df[cols] = df[cols].fillna(0)

df.info();
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104 entries, 0 to 103
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   DATE           104 non-null    datetime64[ns]
#  1   DEBIT          0 non-null      object
#  2   CREDIT         104 non-null    object
#  3   RECIPIENT      104 non-null    object
#  4   Shumai 30 Pcs  104 non-null    float64
#  5   Shumai 20 Pcs  104 non-null    float64
#  6   Shumai 10 Pcs  104 non-null    float64
#  7   PIC            104 non-null    object
# dtypes: datetime64[ns](1), float64(3), object(4)
# memory usage: 6.6+ KB
#         DATE DEBIT  CREDIT               RECIPIENT  Shumai 30 Pcs  \
# 0 2021-01-29   NaN  100000    Intan (pack of 30's)            1.0
# 1 2021-01-29   NaN  200000  Steffie (pack of 60's)            2.0
# 2 2021-01-29   NaN  100000     Ajis (pack of 30's)            1.0
# 3 2021-01-29   NaN  100000     Riri (pack of 30's)            1.0
# 4 2021-01-14   NaN   80000    Afuza (pack of 20's)            0.0
#
#    Shumai 20 Pcs  Shumai 10 Pcs    PIC
# 0            0.0            0.0  Manda
# 1            0.0            0.0  Manda
# 2            0.0            0.0  Manda
# 3            0.0            0.0  Manda
# 4            1.0            0.0  Ambun

# %% [markdown]
# ### Inconsistent Data **#2**

# %% [markdown]
# #### Convert the product's category sales columns into integer

# %%
# Before convert the datatypes, we must ensure that the columns are not int
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104 entries, 0 to 103
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   DATE           104 non-null    datetime64[ns]
#  1   DEBIT          0 non-null      object
#  2   CREDIT         104 non-null    object
#  3   RECIPIENT      104 non-null    object
#  4   Shumai 30 Pcs  104 non-null    float64
#  5   Shumai 20 Pcs  104 non-null    float64
#  6   Shumai 10 Pcs  104 non-null    float64
#  7   PIC            104 non-null    object
# dtypes: datetime64[ns](1), float64(3), object(4)
# memory usage: 6.6+ KB

# %%
# List of columns
listOfProducts = ['Shumai 10 Pcs', 'Shumai 20 Pcs', 'Shumai 30 Pcs']

# Convert into int64
for cols in listOfProducts:
    for i in range(1, len(df)+1):
        df[cols] = df[cols].astype('int64')

df.info();
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104 entries, 0 to 103
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   DATE           104 non-null    datetime64[ns]
#  1   DEBIT          0 non-null      object
#  2   CREDIT         104 non-null    object
#  3   RECIPIENT      104 non-null    object
#  4   Shumai 30 Pcs  104 non-null    int64
#  5   Shumai 20 Pcs  104 non-null    int64
#  6   Shumai 10 Pcs  104 non-null    int64
#  7   PIC            104 non-null    object
# dtypes: datetime64[ns](1), int64(3), object(4)
# memory usage: 6.6+ KB
#         DATE DEBIT  CREDIT               RECIPIENT  Shumai 30 Pcs  \
# 0 2021-01-29   NaN  100000    Intan (pack of 30's)              1
# 1 2021-01-29   NaN  200000  Steffie (pack of 60's)              2
# 2 2021-01-29   NaN  100000     Ajis (pack of 30's)              1
# 3 2021-01-29   NaN  100000     Riri (pack of 30's)              1
# 4 2021-01-14   NaN   80000    Afuza (pack of 20's)              0
#
#    Shumai 20 Pcs  Shumai 10 Pcs    PIC
# 0              0              0  Manda
# 1              0              0  Manda
# 2              0              0  Manda
# 3              0              0  Manda
# 4              1              0  Ambun

# %% [markdown]
# ## Data Selection

# %% [markdown]
# ### Select certain columns

# %%
df.info();
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104 entries, 0 to 103
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   DATE           104 non-null    datetime64[ns]
#  1   DEBIT          0 non-null      object
#  2   CREDIT         104 non-null    object
#  3   RECIPIENT      104 non-null    object
#  4   Shumai 30 Pcs  104 non-null    int64
#  5   Shumai 20 Pcs  104 non-null    int64
#  6   Shumai 10 Pcs  104 non-null    int64
#  7   PIC            104 non-null    object
# dtypes: datetime64[ns](1), int64(3), object(4)
# memory usage: 6.6+ KB
#         DATE DEBIT  CREDIT               RECIPIENT  Shumai 30 Pcs  \
# 0 2021-01-29   NaN  100000    Intan (pack of 30's)              1
# 1 2021-01-29   NaN  200000  Steffie (pack of 60's)              2
# 2 2021-01-29   NaN  100000     Ajis (pack of 30's)              1
# 3 2021-01-29   NaN  100000     Riri (pack of 30's)              1
# 4 2021-01-14   NaN   80000    Afuza (pack of 20's)              0
#
#    Shumai 20 Pcs  Shumai 10 Pcs    PIC
# 0              0              0  Manda
# 1              0              0  Manda
# 2              0              0  Manda
# 3              0              0  Manda
# 4              1              0  Ambun

# %%
# Delete `DEBIT`, `CREDIT`, `RECIPIENT`, and `PIC` since we don't use it
df = df.drop(columns=['DEBIT', 'CREDIT', 'RECIPIENT', 'PIC'])

# %%
df.info();
df.head()
# Successfully deleted
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104 entries, 0 to 103
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   DATE           104 non-null    datetime64[ns]
#  1   Shumai 30 Pcs  104 non-null    int64
#  2   Shumai 20 Pcs  104 non-null    int64
#  3   Shumai 10 Pcs  104 non-null    int64
# dtypes: datetime64[ns](1), int64(3)
# memory usage: 3.4 KB
#         DATE  Shumai 30 Pcs  Shumai 20 Pcs  Shumai 10 Pcs
# 0 2021-01-29              1              0              0
# 1 2021-01-29              2              0              0
# 2 2021-01-29              1              0              0
# 3 2021-01-29              1              0              0
# 4 2021-01-14              0              1              0

# %% [markdown]
# ### Create new column for Chicken Lumpia

# %%
# Assign 0 to a new column
df['Chicken Lumpia 10 Pcs'] = 0

# %%
df
# Out:
#           DATE  Shumai 30 Pcs  Shumai 20 Pcs  Shumai 10 Pcs  \
# 0   2021-01-29              1              0              0
# 1   2021-01-29              2              0              0
# 2   2021-01-29              1              0              0
# 3   2021-01-29              1              0              0
# 4   2021-01-14              0              1              0
# ..         ...            ...            ...            ...
# 99  2021-01-31              2              0              0
# 100 2021-01-31              1              0              0
# 101 2021-01-31              1              0              0
# 102 2021-01-31              2              1              1
# 103 2021-01-31              1              0              0
#
#      Chicken Lumpia 10 Pcs
# 0                        0
# 1                        0
# 2                        0
# 3                        0
# 4                        0
# ..                     ...
# 99                       0
# 100                      0
# 101                      0
# 102                      0
# 103                      0
#
# [104 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104 entries, 0 to 103
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   DATE                   104 non-null    datetime64[ns]
#  1   Shumai 30 Pcs          104 non-null    int64
#  2   Shumai 20 Pcs          104 non-null    int64
#  3   Shumai 10 Pcs          104 non-null    int64
#  4   Chicken Lumpia 10 Pcs  104 non-null    int64
# dtypes: datetime64[ns](1), int64(4)
# memory usage: 4.2 KB

# %% [markdown]
# ## Export the dataframe into excel files

# %%
# Load datasets and convert it into excel based on month of sales's sheets
df = df.to_excel(r"..\..\data\dataCleaningOne\JAN21_dataCleaning.xlsx", index=False)

# %%
# selecting columns where column name contains 'Average' string
# df.filter(like='Average')
