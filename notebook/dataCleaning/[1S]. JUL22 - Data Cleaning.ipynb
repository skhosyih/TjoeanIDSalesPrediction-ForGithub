# %% [markdown]
# # JUL22 - Data Cleaning

# %% [markdown]
# ## Data Gather

# %% [markdown]
# ### Importing libraries and load the datasets

# %%
from datetime import datetime
import pandas as pd
from openpyxl import Workbook
import numpy as np

# %%
#  Load the datasets
df = pd.read_excel(r"..\..\data\gatherData\JUL22_DimsumTJOEAN.xlsx")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   DATE       15 non-null     datetime64[ns]
#  1   DEBIT      10 non-null     object
#  2   CREDIT     27 non-null     object
#  3   RECIPIENT  23 non-null     object
#  4   30         14 non-null     float64
#  5   20         7 non-null      float64
#  6   10         6 non-null      float64
#  7   L          6 non-null      float64
#  8   R          7 non-null      float64
#  9   G          3 non-null      float64
#  10  PIC        15 non-null     object
# dtypes: datetime64[ns](1), float64(6), object(4)
# memory usage: 3.9+ KB

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Inconsistent Data **#1**

# %% [markdown]
# #### Delete `NaN` rows and the inconsistent rows that we don't use

# %% [markdown]
# ##### Delete `NaN` rows

# %%
df.tail()
# Out:
#    DATE  DEBIT   CREDIT RECIPIENT  30  20  10   L   R   G  PIC
# 39  NaT    NaN  rendang       NaN NaN NaN NaN NaN NaN NaN  NaN
# 40  NaT    NaN      NaN       NaN NaN NaN NaN NaN NaN NaN  NaN
# 41  NaT  Ambun   Shumai       280 NaN NaN NaN NaN NaN NaN  NaN
# 42  NaT    NaN   Lumpia       200 NaN NaN NaN NaN NaN NaN  NaN
# 43  NaT    NaN  Rendang        15 NaN NaN NaN NaN NaN NaN  NaN

# %%
# Rows to drop
rowsToDrop = df[df.isnull().all(axis=1)].index
rowsToDrop
# In a beginning of rows, there are also a 'NaN' values
# Out:
# Index([15, 18, 19, 22, 27, 29, 31, 33, 34, 35, 40], dtype='int64')

# %%
# Delete based on the condition
df = df.drop(index=rowsToDrop)

# %%
df.tail()
# There isn't the all columns have 'NaN' values
# Out:
#    DATE  DEBIT   CREDIT RECIPIENT  30  20  10   L   R   G  PIC
# 38  NaT    NaN   Lumpia        40 NaN NaN NaN NaN NaN NaN  NaN
# 39  NaT    NaN  rendang       NaN NaN NaN NaN NaN NaN NaN  NaN
# 41  NaT  Ambun   Shumai       280 NaN NaN NaN NaN NaN NaN  NaN
# 42  NaT    NaN   Lumpia       200 NaN NaN NaN NaN NaN NaN  NaN
# 43  NaT    NaN  Rendang        15 NaN NaN NaN NaN NaN NaN  NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 33 entries, 0 to 43
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   DATE       15 non-null     datetime64[ns]
#  1   DEBIT      10 non-null     object
#  2   CREDIT     27 non-null     object
#  3   RECIPIENT  23 non-null     object
#  4   30         14 non-null     float64
#  5   20         7 non-null      float64
#  6   10         6 non-null      float64
#  7   L          6 non-null      float64
#  8   R          7 non-null      float64
#  9   G          3 non-null      float64
#  10  PIC        15 non-null     object
# dtypes: datetime64[ns](1), float64(6), object(4)
# memory usage: 3.1+ KB

# %% [markdown]
# ##### Delete the inconsistent rows that we don't use

# %%
df.head()
# Out:
#         DATE DEBIT     CREDIT           RECIPIENT    30   20   10     L     R  \
# 0 2022-07-01   NaN  230721025              July's  20.0  4.0  7.0  13.0  15.0
# 1 2022-07-01   NaN     200000           Tante Ida   2.0  NaN  NaN   NaN   NaN
# 2 2022-07-18   NaN     668000  aldhira [reseller]   7.0  NaN  NaN   1.0   NaN
# 3 2022-07-08   NaN     125000            mba ilen   NaN  NaN  NaN   NaN   1.0
# 4 2022-07-07   NaN      80000            mba ilen   NaN  1.0  NaN   NaN   NaN
#
#      G    PIC
# 0  6.0    NaN
# 1  NaN  Ambun
# 2  NaN  Manda
# 3  NaN  Manda
# 4  NaN  Manda

# %%
df.tail(6)
# Out:
#    DATE  DEBIT   CREDIT RECIPIENT  30  20  10   L   R   G  PIC
# 37  NaT  Manda   Shumai        40 NaN NaN NaN NaN NaN NaN  NaN
# 38  NaT    NaN   Lumpia        40 NaN NaN NaN NaN NaN NaN  NaN
# 39  NaT    NaN  rendang       NaN NaN NaN NaN NaN NaN NaN  NaN
# 41  NaT  Ambun   Shumai       280 NaN NaN NaN NaN NaN NaN  NaN
# 42  NaT    NaN   Lumpia       200 NaN NaN NaN NaN NaN NaN  NaN
# 43  NaT    NaN  Rendang        15 NaN NaN NaN NaN NaN NaN  NaN

# %%
# Condition where 'PIC' column values is not Manda and Ambun
rowsToDropIsNotPIC = df[~(df['PIC'].isin(['Manda', 'Ambun']))].index
rowsToDropIsNotPIC
# Out:
# Index([0, 16, 17, 20, 21, 23, 24, 25, 26, 28, 30, 32, 36, 37, 38, 39, 41, 42,
#        43],
#       dtype='int64')

# %%
# Delete based on the condition
df = df.drop(index=rowsToDropIsNotPIC)

# Adjust the index in ascending from start until finish
df = df.reset_index(drop=True)

# %%
df.info()
# Successfully adjust
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   DATE       14 non-null     datetime64[ns]
#  1   DEBIT      0 non-null      object
#  2   CREDIT     14 non-null     object
#  3   RECIPIENT  14 non-null     object
#  4   30         9 non-null      float64
#  5   20         2 non-null      float64
#  6   10         1 non-null      float64
#  7   L          2 non-null      float64
#  8   R          4 non-null      float64
#  9   G          0 non-null      float64
#  10  PIC        14 non-null     object
# dtypes: datetime64[ns](1), float64(6), object(4)
# memory usage: 1.3+ KB

# %%
df.head()
# The first rows that we don't use is successfully deleted
# Out:
#         DATE DEBIT  CREDIT           RECIPIENT   30   20  10    L    R   G  \
# 0 2022-07-01   NaN  200000           Tante Ida  2.0  NaN NaN  NaN  NaN NaN
# 1 2022-07-18   NaN  668000  aldhira [reseller]  7.0  NaN NaN  1.0  NaN NaN
# 2 2022-07-08   NaN  125000            mba ilen  NaN  NaN NaN  NaN  1.0 NaN
# 3 2022-07-07   NaN   80000            mba ilen  NaN  1.0 NaN  NaN  NaN NaN
# 4 2022-07-25   NaN  200000               putka  2.0  NaN NaN  NaN  NaN NaN
#
#      PIC
# 0  Ambun
# 1  Manda
# 2  Manda
# 3  Manda
# 4  Manda

# %%
df.tail()
# The last rows that we don't use is successfully deleted
# Out:
#          DATE DEBIT  CREDIT            RECIPIENT   30  20   10   L    R   G  \
# 9  2022-07-13   NaN  100000              birgita  1.0 NaN  NaN NaN  NaN NaN
# 10 2022-07-25   NaN  100000             mba tora  1.0 NaN  NaN NaN  NaN NaN
# 11 2022-07-25   NaN  225000  Mas dhan for bolang  1.0 NaN  NaN NaN  1.0 NaN
# 12 2022-07-28   NaN  200000                 Aziz  2.0 NaN  NaN NaN  NaN NaN
# 13 2022-07-28   NaN   40000            Mba riksa  NaN NaN  1.0 NaN  NaN NaN
#
#       PIC
# 9   Manda
# 10  Manda
# 11  Manda
# 12  Manda
# 13  Manda

# %% [markdown]
# #### Rename `30`, `20`, `10`, `L` columns to make it easier to understand

# %%
df[[30, 20, 10, 'L']].head()
# Out:
#     30   20  10    L
# 0  2.0  NaN NaN  NaN
# 1  7.0  NaN NaN  1.0
# 2  NaN  NaN NaN  NaN
# 3  NaN  1.0 NaN  NaN
# 4  2.0  NaN NaN  NaN

# %%
# Rename the columns to improve readability
df = df.rename(columns={30:'Shumai 30 Pcs', 20:'Shumai 20 Pcs', 10:'Shumai 10 Pcs', 'L':'Chicken Lumpia 10 Pcs'})

# %%
df[['Shumai 30 Pcs', 'Shumai 20 Pcs', 'Shumai 10 Pcs', 'Chicken Lumpia 10 Pcs']]
# Now, it's getting better
# Out:
#     Shumai 30 Pcs  Shumai 20 Pcs  Shumai 10 Pcs  Chicken Lumpia 10 Pcs
# 0             2.0            NaN            NaN                    NaN
# 1             7.0            NaN            NaN                    1.0
# 2             NaN            NaN            NaN                    NaN
# 3             NaN            1.0            NaN                    NaN
# 4             2.0            NaN            NaN                    NaN
# 5             1.0            NaN            NaN                    NaN
# 6             NaN            NaN            NaN                    NaN
# 7             2.0            NaN            NaN                    NaN
# 8             NaN            1.0            NaN                    1.0
# 9             1.0            NaN            NaN                    NaN
# 10            1.0            NaN            NaN                    NaN
# 11            1.0            NaN            NaN                    NaN
# 12            2.0            NaN            NaN                    NaN
# 13            NaN            NaN            1.0                    NaN

# %%
df.head()
# Out:
#         DATE DEBIT  CREDIT           RECIPIENT  Shumai 30 Pcs  Shumai 20 Pcs  \
# 0 2022-07-01   NaN  200000           Tante Ida            2.0            NaN
# 1 2022-07-18   NaN  668000  aldhira [reseller]            7.0            NaN
# 2 2022-07-08   NaN  125000            mba ilen            NaN            NaN
# 3 2022-07-07   NaN   80000            mba ilen            NaN            1.0
# 4 2022-07-25   NaN  200000               putka            2.0            NaN
#
#    Shumai 10 Pcs  Chicken Lumpia 10 Pcs    R   G    PIC
# 0            NaN                    NaN  NaN NaN  Ambun
# 1            NaN                    1.0  NaN NaN  Manda
# 2            NaN                    NaN  1.0 NaN  Manda
# 3            NaN                    NaN  NaN NaN  Manda
# 4            NaN                    NaN  NaN NaN  Manda

# %% [markdown]
# ### Missing Value

# %% [markdown]
# #### Impute missing values of `DATE` column with mode

# %%
df.info();
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   DATE                   14 non-null     datetime64[ns]
#  1   DEBIT                  0 non-null      object
#  2   CREDIT                 14 non-null     object
#  3   RECIPIENT              14 non-null     object
#  4   Shumai 30 Pcs          9 non-null      float64
#  5   Shumai 20 Pcs          2 non-null      float64
#  6   Shumai 10 Pcs          1 non-null      float64
#  7   Chicken Lumpia 10 Pcs  2 non-null      float64
#  8   R                      4 non-null      float64
#  9   G                      0 non-null      float64
#  10  PIC                    14 non-null     object
# dtypes: datetime64[ns](1), float64(6), object(4)
# memory usage: 1.3+ KB
#         DATE DEBIT  CREDIT           RECIPIENT  Shumai 30 Pcs  Shumai 20 Pcs  \
# 0 2022-07-01   NaN  200000           Tante Ida            2.0            NaN
# 1 2022-07-18   NaN  668000  aldhira [reseller]            7.0            NaN
# 2 2022-07-08   NaN  125000            mba ilen            NaN            NaN
# 3 2022-07-07   NaN   80000            mba ilen            NaN            1.0
# 4 2022-07-25   NaN  200000               putka            2.0            NaN
#
#    Shumai 10 Pcs  Chicken Lumpia 10 Pcs    R   G    PIC
# 0            NaN                    NaN  NaN NaN  Ambun
# 1            NaN                    1.0  NaN NaN  Manda
# 2            NaN                    NaN  1.0 NaN  Manda
# 3            NaN                    NaN  NaN NaN  Manda
# 4            NaN                    NaN  NaN NaN  Manda

# %%
df['DATE'].mode()
# Out:
# 0   2022-07-25
# Name: DATE, dtype: datetime64[ns]

# %%
# Impute missing values of `DATE` column with mode
df['DATE'] = df['DATE'].fillna(df['DATE'].mode()[0])

# %%
df.info();
df.head()
# Successfully fill with mode
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   DATE                   14 non-null     datetime64[ns]
#  1   DEBIT                  0 non-null      object
#  2   CREDIT                 14 non-null     object
#  3   RECIPIENT              14 non-null     object
#  4   Shumai 30 Pcs          9 non-null      float64
#  5   Shumai 20 Pcs          2 non-null      float64
#  6   Shumai 10 Pcs          1 non-null      float64
#  7   Chicken Lumpia 10 Pcs  2 non-null      float64
#  8   R                      4 non-null      float64
#  9   G                      0 non-null      float64
#  10  PIC                    14 non-null     object
# dtypes: datetime64[ns](1), float64(6), object(4)
# memory usage: 1.3+ KB
#         DATE DEBIT  CREDIT           RECIPIENT  Shumai 30 Pcs  Shumai 20 Pcs  \
# 0 2022-07-01   NaN  200000           Tante Ida            2.0            NaN
# 1 2022-07-18   NaN  668000  aldhira [reseller]            7.0            NaN
# 2 2022-07-08   NaN  125000            mba ilen            NaN            NaN
# 3 2022-07-07   NaN   80000            mba ilen            NaN            1.0
# 4 2022-07-25   NaN  200000               putka            2.0            NaN
#
#    Shumai 10 Pcs  Chicken Lumpia 10 Pcs    R   G    PIC
# 0            NaN                    NaN  NaN NaN  Ambun
# 1            NaN                    1.0  NaN NaN  Manda
# 2            NaN                    NaN  1.0 NaN  Manda
# 3            NaN                    NaN  NaN NaN  Manda
# 4            NaN                    NaN  NaN NaN  Manda

# %% [markdown]
# ### Inconsistent Data **#2**

# %% [markdown]
# #### Convert `DATE` column into the sum of the month selecting column that we want to use

# %%
# Turn 'DATE' into per month
df['DATE'] = df['DATE'].dt.to_period('M')

# Sum of the month and selecting column that we want to use
df = df.groupby('DATE')[['Shumai 30 Pcs', 'Shumai 20 Pcs', 'Shumai 10 Pcs', 'Chicken Lumpia 10 Pcs']].sum().reset_index()

# %%
df.head()
# Out:
#       DATE  Shumai 30 Pcs  Shumai 20 Pcs  Shumai 10 Pcs  Chicken Lumpia 10 Pcs
# 0  2022-07           19.0            2.0            1.0                    2.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   DATE                   1 non-null      period[M]
#  1   Shumai 30 Pcs          1 non-null      float64
#  2   Shumai 20 Pcs          1 non-null      float64
#  3   Shumai 10 Pcs          1 non-null      float64
#  4   Chicken Lumpia 10 Pcs  1 non-null      float64
# dtypes: float64(4), period[M](1)
# memory usage: 172.0 bytes

# %% [markdown]
# #### Convert the products category sales columns into integer

# %%
# Before convert the datatypes, we must ensure that the columns are not int
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   DATE                   1 non-null      period[M]
#  1   Shumai 30 Pcs          1 non-null      float64
#  2   Shumai 20 Pcs          1 non-null      float64
#  3   Shumai 10 Pcs          1 non-null      float64
#  4   Chicken Lumpia 10 Pcs  1 non-null      float64
# dtypes: float64(4), period[M](1)
# memory usage: 172.0 bytes

# %%
# Convert into int64
df = df.astype({'Shumai 30 Pcs':'int64', 'Shumai 20 Pcs':'int64', 
                'Shumai 10 Pcs':'int64', 'Chicken Lumpia 10 Pcs':'int64'})

# %%
df.info();
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   DATE                   1 non-null      period[M]
#  1   Shumai 30 Pcs          1 non-null      int64
#  2   Shumai 20 Pcs          1 non-null      int64
#  3   Shumai 10 Pcs          1 non-null      int64
#  4   Chicken Lumpia 10 Pcs  1 non-null      int64
# dtypes: int64(4), period[M](1)
# memory usage: 172.0 bytes
#       DATE  Shumai 30 Pcs  Shumai 20 Pcs  Shumai 10 Pcs  Chicken Lumpia 10 Pcs
# 0  2022-07             19              2              1                      2

# %% [markdown]
# ## Export the dataframe into excel files

# %%
# Load datasets and convert it into excel based on month of sales's sheets
df = df.to_excel(r"..\..\data\dataCleaning\JUL22_dataCleaning.xlsx", index=False)

# %%
# selecting columns where column name contains 'Average' string
# df.filter(like='Average')
